# %%
from IPython.display import display, Markdown
import numpy as np
def set_frame_style(df, caption="", font_size ='20px' ):
    random_list = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
                      'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
                      'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
    """Helper function to set dataframe presentation style.
    """
    return df.style.background_gradient(cmap=random_list[np.random.randint(1,17)]).set_caption(caption).set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Brown'),
        ('font-size', font_size),
        ('font-weight','bold')
    ]}])

# %% [markdown]
# # <center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Table of contents </p>   </span></font></center>
#
# # Table of Contents

# %% [markdown]
# <a id="toc"></a>
# - [About the dataset](#1)
#     - [1.1 Dataset Description](#1.1)
# - [2. Importing the data](#2)
#     - [2.1 Columns creation](#2.1)
# - [3. Exploratory Data Analysis](#3)
#     - [3.1 Distribution of Features](#3.1)
#     - [3.2 Insights](#3.2)
# - [4. Preprocessing](#4)
#     - [4.1 RobustScaler](#4.1)
#     - [4.2 One Hot Encoding](#4.2)
# - [5. Model Training](#5)
#     - [5.1 XGB Classifier](#5.1)
#     - [5.2 LGBM Classifier](#5.2)
#     - [5.3 CatBoost Classifier](#5.3)
#     - [5.4  Hyperparameter Optimization](#5.4)
#     - [5.5 Ensemble(XGB, LGBM, CatBoost](#5.5)
# - [6. Model Inference](#6)
#     - [6.1 Feature Importance](#6.1)

# %% [markdown]
# # <a id="1"></a><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">About the dataset </p>   </span></font></center>
#
# # About the dataset
#
#
# - Liver cirrhosis : A complication that happens with a body organ, liver. Cirrhosis results from prolonged liver damage, leading to extensive scarring, often due to conditions like hepatitis or chronic alcohol consumption.
# - We need to use  17 (clinical) features to predict survival of patient with liver
# - 3 classes : 0 = D (death), 1 = C (censored), 2 = CL (censored due to liver transplantation)
#  > - Class 0 (D): The patient didn't survived.
# > - Class 1 (C): The patient is censored, meaning that the observation period ended without the event (death) occurring. This means patient still being alive at the time of studyinh this.
# > - Class 2 (CL): Similar to Class 1, the patient is censored, but the reason for censorship is specifically due to liver transplantation.
# - Was there any data preprocessing performed? yes
# > - Dropped all the rows where missing values (NA) were present in the `Drug` column
# > - Imputed missing values with mean results
# > - One-hot encoded for all category attributes

# %% [markdown]
# # <a id="2"></a><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Importing the data </p>   </span></font></center>
#
# #  💽 Importing the data

# %%
import pandas as pd
syn_df= pd.read_csv('/kaggle/input/playground-series-s3e26/train.csv')
original_df = pd.read_csv('/kaggle/input/cirrhosis-patient-survival-prediction/cirrhosis.csv')

test_df = pd.read_csv('/kaggle/input/playground-series-s3e26/test.csv')
ids = test_df['id']
syn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7905 entries, 0 to 7904
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             7905 non-null   int64
#  1   N_Days         7905 non-null   int64
#  2   Drug           7905 non-null   object
#  3   Age            7905 non-null   int64
#  4   Sex            7905 non-null   object
#  5   Ascites        7905 non-null   object
#  6   Hepatomegaly   7905 non-null   object
#  7   Spiders        7905 non-null   object
#  8   Edema          7905 non-null   object
#  9   Bilirubin      7905 non-null   float64
#  10  Cholesterol    7905 non-null   float64
#  11  Albumin        7905 non-null   float64
#  12  Copper         7905 non-null   float64
#  13  Alk_Phos       7905 non-null   float64
#  14  SGOT           7905 non-null   float64
#  15  Tryglicerides  7905 non-null   float64
#  16  Platelets      7905 non-null   float64
#  17  Prothrombin    7905 non-null   float64
#  18  Stage          7905 non-null   float64
#  19  Status         7905 non-null   object
# dtypes: float64(10), int64(3), object(7)
# memory usage: 1.2+ MB

# %%
original_df.columns = ['id', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
       'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
       'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
       'Prothrombin', 'Stage']

# %%
set_frame_style(syn_df.head(),'Synthetically Generated Data\n')
# Out:
# <style type="text/css">
# #T_21b5f caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_21b5f_row0_col0, #T_21b5f_row0_col11, #T_21b5f_row0_col17, #T_21b5f_row0_col18, #T_21b5f_row1_col18, #T_21b5f_row2_col3, #T_21b5f_row2_col13, #T_21b5f_row2_col15, #T_21b5f_row2_col16, #T_21b5f_row3_col9, #T_21b5f_row3_col10, #T_21b5f_row3_col12, #T_21b5f_row3_col14, #T_21b5f_row3_col18, #T_21b5f_row4_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_21b5f_row0_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_21b5f_row0_col3, #T_21b5f_row0_col12, #T_21b5f_row0_col14, #T_21b5f_row0_col16, #T_21b5f_row1_col10, #T_21b5f_row2_col1, #T_21b5f_row2_col9, #T_21b5f_row2_col17, #T_21b5f_row2_col18, #T_21b5f_row3_col13, #T_21b5f_row3_col15, #T_21b5f_row4_col0, #T_21b5f_row4_col11, #T_21b5f_row4_col15, #T_21b5f_row4_col18 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_21b5f_row0_col9 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_21b5f_row0_col10 {
#   background-color: #908dc2;
#   color: #f1f1f1;
# }
# #T_21b5f_row0_col13 {
#   background-color: #4d1a89;
#   color: #f1f1f1;
# }
# #T_21b5f_row0_col15 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_21b5f_row1_col0 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_21b5f_row1_col1, #T_21b5f_row3_col1 {
#   background-color: #776ab0;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col3 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col9 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_21b5f_row1_col11 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col12, #T_21b5f_row4_col12 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_21b5f_row1_col13 {
#   background-color: #7a71b4;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col14 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col15 {
#   background-color: #5c3797;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col16 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_21b5f_row1_col17 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_21b5f_row2_col0, #T_21b5f_row3_col11, #T_21b5f_row3_col17 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_21b5f_row2_col10 {
#   background-color: #b7b7d9;
#   color: #000000;
# }
# #T_21b5f_row2_col11 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_21b5f_row2_col12 {
#   background-color: #7d78b7;
#   color: #f1f1f1;
# }
# #T_21b5f_row2_col14 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_21b5f_row3_col0 {
#   background-color: #6950a3;
#   color: #f1f1f1;
# }
# #T_21b5f_row3_col3 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_21b5f_row3_col16 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_21b5f_row4_col3 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_21b5f_row4_col9 {
#   background-color: #e5e4f0;
#   color: #000000;
# }
# #T_21b5f_row4_col10 {
#   background-color: #5b3495;
#   color: #f1f1f1;
# }
# #T_21b5f_row4_col13 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_21b5f_row4_col14 {
#   background-color: #9e9bc8;
#   color: #f1f1f1;
# }
# #T_21b5f_row4_col16 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_21b5f_row4_col17 {
#   background-color: #aaa8d0;
#   color: #000000;
# }
# </style>
# <table id="T_21b5f">
#   <caption>Synthetically Generated Data
# </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21b5f_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_21b5f_level0_col1" class="col_heading level0 col1" >N_Days</th>
#       <th id="T_21b5f_level0_col2" class="col_heading level0 col2" >Drug</th>
#       <th id="T_21b5f_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_21b5f_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_21b5f_level0_col5" class="col_heading level0 col5" >Ascites</th>
#       <th id="T_21b5f_level0_col6" class="col_heading level0 col6" >Hepatomegaly</th>
#       <th id="T_21b5f_level0_col7" class="col_heading level0 col7" >Spiders</th>
#       <th id="T_21b5f_level0_col8" class="col_heading level0 col8" >Edema</th>
#       <th id="T_21b5f_level0_col9" class="col_heading level0 col9" >Bilirubin</th>
#       <th id="T_21b5f_level0_col10" class="col_heading level0 col10" >Cholesterol</th>
#       <th id="T_21b5f_level0_col11" class="col_heading level0 col11" >Albumin</th>
#       <th id="T_21b5f_level0_col12" class="col_heading level0 col12" >Copper</th>
#       <th id="T_21b5f_level0_col13" class="col_heading level0 col13" >Alk_Phos</th>
#       <th id="T_21b5f_level0_col14" class="col_heading level0 col14" >SGOT</th>
#       <th id="T_21b5f_level0_col15" class="col_heading level0 col15" >Tryglicerides</th>
#       <th id="T_21b5f_level0_col16" class="col_heading level0 col16" >Platelets</th>
#       <th id="T_21b5f_level0_col17" class="col_heading level0 col17" >Prothrombin</th>
#       <th id="T_21b5f_level0_col18" class="col_heading level0 col18" >Stage</th>
#       <th id="T_21b5f_level0_col19" class="col_heading level0 col19" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21b5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21b5f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_21b5f_row0_col1" class="data row0 col1" >999</td>
#       <td id="T_21b5f_row0_col2" class="data row0 col2" >D-penicillamine</td>
#       <td id="T_21b5f_row0_col3" class="data row0 col3" >21532</td>
#       <td id="T_21b5f_row0_col4" class="data row0 col4" >M</td>
#       <td id="T_21b5f_row0_col5" class="data row0 col5" >N</td>
#       <td id="T_21b5f_row0_col6" class="data row0 col6" >N</td>
#       <td id="T_21b5f_row0_col7" class="data row0 col7" >N</td>
#       <td id="T_21b5f_row0_col8" class="data row0 col8" >N</td>
#       <td id="T_21b5f_row0_col9" class="data row0 col9" >2.300000</td>
#       <td id="T_21b5f_row0_col10" class="data row0 col10" >316.000000</td>
#       <td id="T_21b5f_row0_col11" class="data row0 col11" >3.350000</td>
#       <td id="T_21b5f_row0_col12" class="data row0 col12" >172.000000</td>
#       <td id="T_21b5f_row0_col13" class="data row0 col13" >1601.000000</td>
#       <td id="T_21b5f_row0_col14" class="data row0 col14" >179.800000</td>
#       <td id="T_21b5f_row0_col15" class="data row0 col15" >63.000000</td>
#       <td id="T_21b5f_row0_col16" class="data row0 col16" >394.000000</td>
#       <td id="T_21b5f_row0_col17" class="data row0 col17" >9.700000</td>
#       <td id="T_21b5f_row0_col18" class="data row0 col18" >3.000000</td>
#       <td id="T_21b5f_row0_col19" class="data row0 col19" >D</td>
#     </tr>
#     <tr>
#       <th id="T_21b5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21b5f_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_21b5f_row1_col1" class="data row1 col1" >2574</td>
#       <td id="T_21b5f_row1_col2" class="data row1 col2" >Placebo</td>
#       <td id="T_21b5f_row1_col3" class="data row1 col3" >19237</td>
#       <td id="T_21b5f_row1_col4" class="data row1 col4" >F</td>
#       <td id="T_21b5f_row1_col5" class="data row1 col5" >N</td>
#       <td id="T_21b5f_row1_col6" class="data row1 col6" >N</td>
#       <td id="T_21b5f_row1_col7" class="data row1 col7" >N</td>
#       <td id="T_21b5f_row1_col8" class="data row1 col8" >N</td>
#       <td id="T_21b5f_row1_col9" class="data row1 col9" >0.900000</td>
#       <td id="T_21b5f_row1_col10" class="data row1 col10" >364.000000</td>
#       <td id="T_21b5f_row1_col11" class="data row1 col11" >3.540000</td>
#       <td id="T_21b5f_row1_col12" class="data row1 col12" >63.000000</td>
#       <td id="T_21b5f_row1_col13" class="data row1 col13" >1440.000000</td>
#       <td id="T_21b5f_row1_col14" class="data row1 col14" >134.850000</td>
#       <td id="T_21b5f_row1_col15" class="data row1 col15" >88.000000</td>
#       <td id="T_21b5f_row1_col16" class="data row1 col16" >361.000000</td>
#       <td id="T_21b5f_row1_col17" class="data row1 col17" >11.000000</td>
#       <td id="T_21b5f_row1_col18" class="data row1 col18" >3.000000</td>
#       <td id="T_21b5f_row1_col19" class="data row1 col19" >C</td>
#     </tr>
#     <tr>
#       <th id="T_21b5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21b5f_

# %%
set_frame_style(original_df.head(),'Original Data\n')
# Out:
# <style type="text/css">
# #T_4b813 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_4b813_row0_col0, #T_4b813_row0_col1, #T_4b813_row1_col10, #T_4b813_row1_col13, #T_4b813_row1_col19, #T_4b813_row2_col11, #T_4b813_row2_col14, #T_4b813_row2_col16, #T_4b813_row3_col12, #T_4b813_row3_col15, #T_4b813_row3_col18, #T_4b813_row4_col4, #T_4b813_row4_col17, #T_4b813_row4_col19 {
#   background-color: #f7f4f9;
#   color: #000000;
# }
# #T_4b813_row0_col4 {
#   background-color: #e32581;
#   color: #f1f1f1;
# }
# #T_4b813_row0_col10, #T_4b813_row0_col15, #T_4b813_row0_col16, #T_4b813_row0_col18, #T_4b813_row0_col19, #T_4b813_row1_col1, #T_4b813_row1_col11, #T_4b813_row1_col12, #T_4b813_row1_col14, #T_4b813_row1_col17, #T_4b813_row2_col4, #T_4b813_row2_col13, #T_4b813_row2_col19, #T_4b813_row3_col19, #T_4b813_row4_col0 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_4b813_row0_col11 {
#   background-color: #dd2075;
#   color: #f1f1f1;
# }
# #T_4b813_row0_col12 {
#   background-color: #f2eff6;
#   color: #000000;
# }
# #T_4b813_row0_col13 {
#   background-color: #e1237e;
#   color: #f1f1f1;
# }
# #T_4b813_row0_col14 {
#   background-color: #e0d2e7;
#   color: #000000;
# }
# #T_4b813_row0_col17 {
#   background-color: #e52786;
#   color: #f1f1f1;
# }
# #T_4b813_row1_col0 {
#   background-color: #d4b9da;
#   color: #000000;
# }
# #T_4b813_row1_col4, #T_4b813_row4_col13 {
#   background-color: #e4429a;
#   color: #f1f1f1;
# }
# #T_4b813_row1_col15 {
#   background-color: #db1e71;
#   color: #f1f1f1;
# }
# #T_4b813_row1_col16 {
#   background-color: #d1afd5;
#   color: #000000;
# }
# #T_4b813_row1_col18 {
#   background-color: #e2d7ea;
#   color: #000000;
# }
# #T_4b813_row2_col0 {
#   background-color: #df64af;
#   color: #f1f1f1;
# }
# #T_4b813_row2_col1 {
#   background-color: #e3d9eb;
#   color: #000000;
# }
# #T_4b813_row2_col10, #T_4b813_row4_col14 {
#   background-color: #f4f1f7;
#   color: #000000;
# }
# #T_4b813_row2_col12 {
#   background-color: #e53b95;
#   color: #f1f1f1;
# }
# #T_4b813_row2_col15 {
#   background-color: #d874b8;
#   color: #f1f1f1;
# }
# #T_4b813_row2_col17 {
#   background-color: #dfd1e6;
#   color: #000000;
# }
# #T_4b813_row2_col18 {
#   background-color: #8f003c;
#   color: #f1f1f1;
# }
# #T_4b813_row3_col0 {
#   background-color: #cd1256;
#   color: #f1f1f1;
# }
# #T_4b813_row3_col1 {
#   background-color: #c995c7;
#   color: #f1f1f1;
# }
# #T_4b813_row3_col4 {
#   background-color: #e05ba9;
#   color: #f1f1f1;
# }
# #T_4b813_row3_col10 {
#   background-color: #f0ecf5;
#   color: #000000;
# }
# #T_4b813_row3_col11 {
#   background-color: #e251a3;
#   color: #f1f1f1;
# }
# #T_4b813_row3_col13 {
#   background-color: #efeaf4;
#   color: #000000;
# }
# #T_4b813_row3_col14 {
#   background-color: #b2094c;
#   color: #f1f1f1;
# }
# #T_4b813_row3_col16, #T_4b813_row4_col18 {
#   background-color: #cea6d0;
#   color: #000000;
# }
# #T_4b813_row3_col17 {
#   background-color: #e24ca0;
#   color: #f1f1f1;
# }
# #T_4b813_row4_col1 {
#   background-color: #d3b4d7;
#   color: #000000;
# }
# #T_4b813_row4_col10 {
#   background-color: #e0d3e8;
#   color: #000000;
# }
# #T_4b813_row4_col11 {
#   background-color: #b0084b;
#   color: #f1f1f1;
# }
# #T_4b813_row4_col12 {
#   background-color: #e72c8c;
#   color: #f1f1f1;
# }
# #T_4b813_row4_col15 {
#   background-color: #dc1f74;
#   color: #f1f1f1;
# }
# #T_4b813_row4_col16 {
#   background-color: #e4dbec;
#   color: #000000;
# }
# </style>
# <table id="T_4b813">
#   <caption>Original Data
# </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b813_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_4b813_level0_col1" class="col_heading level0 col1" >N_Days</th>
#       <th id="T_4b813_level0_col2" class="col_heading level0 col2" >Status</th>
#       <th id="T_4b813_level0_col3" class="col_heading level0 col3" >Drug</th>
#       <th id="T_4b813_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_4b813_level0_col5" class="col_heading level0 col5" >Sex</th>
#       <th id="T_4b813_level0_col6" class="col_heading level0 col6" >Ascites</th>
#       <th id="T_4b813_level0_col7" class="col_heading level0 col7" >Hepatomegaly</th>
#       <th id="T_4b813_level0_col8" class="col_heading level0 col8" >Spiders</th>
#       <th id="T_4b813_level0_col9" class="col_heading level0 col9" >Edema</th>
#       <th id="T_4b813_level0_col10" class="col_heading level0 col10" >Bilirubin</th>
#       <th id="T_4b813_level0_col11" class="col_heading level0 col11" >Cholesterol</th>
#       <th id="T_4b813_level0_col12" class="col_heading level0 col12" >Albumin</th>
#       <th id="T_4b813_level0_col13" class="col_heading level0 col13" >Copper</th>
#       <th id="T_4b813_level0_col14" class="col_heading level0 col14" >Alk_Phos</th>
#       <th id="T_4b813_level0_col15" class="col_heading level0 col15" >SGOT</th>
#       <th id="T_4b813_level0_col16" class="col_heading level0 col16" >Tryglicerides</th>
#       <th id="T_4b813_level0_col17" class="col_heading level0 col17" >Platelets</th>
#       <th id="T_4b813_level0_col18" class="col_heading level0 col18" >Prothrombin</th>
#       <th id="T_4b813_level0_col19" class="col_heading level0 col19" >Stage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b813_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b813_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4b813_row0_col1" class="data row0 col1" >400</td>
#       <td id="T_4b813_row0_col2" class="data row0 col2" >D</td>
#       <td id="T_4b813_row0_col3" class="data row0 col3" >D-penicillamine</td>
#       <td id="T_4b813_row0_col4" class="data row0 col4" >21464</td>
#       <td id="T_4b813_row0_col5" class="data row0 col5" >F</td>
#       <td id="T_4b813_row0_col6" class="data row0 col6" >Y</td>
#       <td id="T_4b813_row0_col7" class="data row0 col7" >Y</td>
#       <td id="T_4b813_row0_col8" class="data row0 col8" >Y</td>
#       <td id="T_4b813_row0_col9" class="data row0 col9" >Y</td>
#       <td id="T_4b813_row0_col10" class="data row0 col10" >14.500000</td>
#       <td id="T_4b813_row0_col11" class="data row0 col11" >261.000000</td>
#       <td id="T_4b813_row0_col12" class="data row0 col12" >2.600000</td>
#       <td id="T_4b813_row0_col13" class="data row0 col13" >156.000000</td>
#       <td id="T_4b813_row0_col14" class="data row0 col14" >1718.000000</td>
#       <td id="T_4b813_row0_col15" class="data row0 col15" >137.950000</td>
#       <td id="T_4b813_row0_col16" class="data row0 col16" >172.000000</td>
#       <td id="T_4b813_row0_col17" class="data row0 col17" >190.000000</td>
#       <td id="T_4b813_row0_col18" class="data row0 col18" >12.200000</td>
#       <td id="T_4b813_row0_col19" class="data row0 col19" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4b813_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b813_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4b813_row1_col1" class="data row1 col1" >4500</td>
#       <td id="T_4b813_row1_col2" class="data row1 col2" >C</td>
#       <td id="T_4b813_row1_col3" class="data row1 col3" >D-penicillamine</td>
#       <td id="T_4b813_row1_col4" class="data row1 col4" >20617</td>
#       <td id="T_4b813_row1_col5" class="data row1 col5" >F</td>
#       <td id="T_4b813_row1_col6" class="data row1 col6" >N</td>
#       <td id="T_4b813_row1_col7" class="data row1 col7" >Y</td>
#       <td id="T_4b813_row1_col8" class="data row1 col8" >Y</td>
#       <td id="T_4b813_row1_col9" class="data row1 col9" >N</td>
#       <td id="T_4b813_row1_col10" class="data row1 col10" >1.100000</td>
#       <td id="T_4b813_row1_col11" class="data row1 col11" >302.000000</td>
#       <td id="T_4b813_row1_col12" class="data row1 col12" >4.140000</td>
#       <td id="T_4b813_row1_col13" class="data row1 col13" >54.000000</td>
#       <td id="T_4b813_row1_col14" class="data row1 col14" >7394.800000</td>
#       <td id="T_4b813_row1_col15" class="data row1 col15" >113.520000</td>
#       <td id="T_4b813_row1_col16" class="data row1 col16" >88.000000</td>
#       <td id="T_4b813_row1_col17" class="data row1 col17" >221.000000</td>
#       <td id="T_4b813_row1_col18" class="data row1 col18" >10.600000</td>
#       <td id="T_4b813_row1_col19" class="data row1 col19" >3.000000</td>
#     </tr>
#     <

# %%
from prettytable import PrettyTable


table = PrettyTable()
table.field_names = ["Features","Unique Values"]
for i in list(syn_df.columns) :
    nunique =syn_df[str(i)].nunique
    table.add_row([i, f"{nunique()}"])
print('Unique values in synthetically generated dataset : \n')
print(table)
# Out:
# Unique values in synthetically generated dataset :
#
# +---------------+---------------+
# |    Features   | Unique Values |
# +---------------+---------------+
# |       id      |      7905     |
# |     N_Days    |      461      |
# |      Drug     |       2       |
# |      Age      |      391      |
# |      Sex      |       2       |
# |    Ascites    |       2       |
# |  Hepatomegaly |       2       |
# |    Spiders    |       2       |
# |     Edema     |       3       |
# |   Bilirubin   |      111      |
# |  Cholesterol  |      226      |
# |    Albumin    |      160      |
# |     Copper    |      171      |
# |    Alk_Phos   |      364      |
# |      SGOT     |      206      |
# | Tryglicerides |      154      |
# |   Platelets   |      227      |
# |  Prothrombin  |       49      |
# |     Stage     |       4       |
# |     Status    |       3       |
# +---------------+---------------+

# %% [markdown]
# ## `Drug`, `Sex` , `Ascites`, ` Hepatomegaly`, `Spiders`, `Edema`, and `Stage` are the categorical features

# %%
from prettytable import PrettyTable


table = PrettyTable()
table.field_names = ["Features","Unique Values"]
for i in list(original_df.columns) :
    nunique =original_df[str(i)].nunique
    table.add_row([i, f"{nunique()}"])
print('Unique values in original dataset : \n')
print(table)
# Out:
# Unique values in original dataset :
#
# +---------------+---------------+
# |    Features   | Unique Values |
# +---------------+---------------+
# |       id      |      418      |
# |     N_Days    |      399      |
# |     Status    |       3       |
# |      Drug     |       2       |
# |      Age      |      344      |
# |      Sex      |       2       |
# |    Ascites    |       2       |
# |  Hepatomegaly |       2       |
# |    Spiders    |       2       |
# |     Edema     |       3       |
# |   Bilirubin   |       98      |
# |  Cholesterol  |      201      |
# |    Albumin    |      154      |
# |     Copper    |      158      |
# |    Alk_Phos   |      295      |
# |      SGOT     |      179      |
# | Tryglicerides |      146      |
# |   Platelets   |      243      |
# |  Prothrombin  |       48      |
# |     Stage     |       4       |
# +---------------+---------------+

# %% [markdown]
#  > ### Both are similar (of course it was synthetically generated from the original one, but it's a good practice to check when merging both dataframes)

# %%
df = pd.concat([syn_df,original_df], axis =0)

df = df.dropna()
df = df.sample(frac = 1).reset_index(drop = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8181 entries, 0 to 8180
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             8181 non-null   int64
#  1   N_Days         8181 non-null   int64
#  2   Drug           8181 non-null   object
#  3   Age            8181 non-null   int64
#  4   Sex            8181 non-null   object
#  5   Ascites        8181 non-null   object
#  6   Hepatomegaly   8181 non-null   object
#  7   Spiders        8181 non-null   object
#  8   Edema          8181 non-null   object
#  9   Bilirubin      8181 non-null   float64
#  10  Cholesterol    8181 non-null   float64
#  11  Albumin        8181 non-null   float64
#  12  Copper         8181 non-null   float64
#  13  Alk_Phos       8181 non-null   float64
#  14  SGOT           8181 non-null   float64
#  15  Tryglicerides  8181 non-null   float64
#  16  Platelets      8181 non-null   float64
#  17  Prothrombin    8181 non-null   float64
#  18  Stage          8181 non-null   float64
#  19  Status         8181 non-null   object
# dtypes: float64(10), int64(3), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# # <a id="2.1"></a><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Columns creation/ Feature Engineering</p>   </span></font></center>
#
# # 💻 Feature Engineering
#
# ### Based on the normal levels of these features in body, we have created several categorical columns and will observe their effect

# %%
def convert_days_to_years(age_in_days):
    days_in_year = 365.25
    age_in_years = age_in_days / days_in_year
    return age_in_years


def add_cols(df):
        age = list(df.Age)
        age_in_year = []
        for i in age :
            age_in_year.append(int(convert_days_to_years(i)))
        df['Age_in_year'] = pd.Series(age_in_year)
        return df
df = add_cols(df)
original_df = add_cols(original_df)
set_frame_style(df.head())
# Out:
# <style type="text/css">
# #T_7df61 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_7df61_row0_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_7df61_row0_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_7df61_row0_col3, #T_7df61_row0_col20, #T_7df61_row1_col0, #T_7df61_row1_col12, #T_7df61_row1_col13, #T_7df61_row1_col15, #T_7df61_row1_col17, #T_7df61_row1_col18, #T_7df61_row2_col1, #T_7df61_row2_col9, #T_7df61_row2_col14, #T_7df61_row3_col11, #T_7df61_row4_col10, #T_7df61_row4_col16 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7df61_row0_col9 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_7df61_row0_col10 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_7df61_row0_col11, #T_7df61_row3_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_7df61_row0_col12, #T_7df61_row0_col14, #T_7df61_row1_col1, #T_7df61_row1_col11, #T_7df61_row1_col16, #T_7df61_row2_col0, #T_7df61_row2_col13, #T_7df61_row2_col17, #T_7df61_row2_col18, #T_7df61_row3_col3, #T_7df61_row3_col9, #T_7df61_row3_col10, #T_7df61_row3_col15, #T_7df61_row3_col17, #T_7df61_row3_col20 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7df61_row0_col13, #T_7df61_row2_col16 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7df61_row0_col15 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_7df61_row0_col16 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_7df61_row0_col17 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_7df61_row0_col18, #T_7df61_row3_col18 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7df61_row1_col3, #T_7df61_row1_col20 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_7df61_row1_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7df61_row1_col10 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_7df61_row1_col14 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_7df61_row2_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_7df61_row2_col10, #T_7df61_row3_col13 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_7df61_row2_col11 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_7df61_row2_col12 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_7df61_row2_col15 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_7df61_row2_col20 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_7df61_row3_col0 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_7df61_row3_col12, #T_7df61_row4_col12 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_7df61_row3_col14 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_7df61_row3_col16 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_7df61_row4_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_7df61_row4_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_7df61_row4_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_7df61_row4_col9 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_7df61_row4_col11 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_7df61_row4_col13 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7df61_row4_col14 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_7df61_row4_col15 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_7df61_row4_col17 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_7df61_row4_col18 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_7df61_row4_col20 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# </style>
# <table id="T_7df61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7df61_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_7df61_level0_col1" class="col_heading level0 col1" >N_Days</th>
#       <th id="T_7df61_level0_col2" class="col_heading level0 col2" >Drug</th>
#       <th id="T_7df61_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_7df61_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_7df61_level0_col5" class="col_heading level0 col5" >Ascites</th>
#       <th id="T_7df61_level0_col6" class="col_heading level0 col6" >Hepatomegaly</th>
#       <th id="T_7df61_level0_col7" class="col_heading level0 col7" >Spiders</th>
#       <th id="T_7df61_level0_col8" class="col_heading level0 col8" >Edema</th>
#       <th id="T_7df61_level0_col9" class="col_heading level0 col9" >Bilirubin</th>
#       <th id="T_7df61_level0_col10" class="col_heading level0 col10" >Cholesterol</th>
#       <th id="T_7df61_level0_col11" class="col_heading level0 col11" >Albumin</th>
#       <th id="T_7df61_level0_col12" class="col_heading level0 col12" >Copper</th>
#       <th id="T_7df61_level0_col13" class="col_heading level0 col13" >Alk_Phos</th>
#       <th id="T_7df61_level0_col14" class="col_heading level0 col14" >SGOT</th>
#       <th id="T_7df61_level0_col15" class="col_heading level0 col15" >Tryglicerides</th>
#       <th id="T_7df61_level0_col16" class="col_heading level0 col16" >Platelets</th>
#       <th id="T_7df61_level0_col17" class="col_heading level0 col17" >Prothrombin</th>
#       <th id="T_7df61_level0_col18" class="col_heading level0 col18" >Stage</th>
#       <th id="T_7df61_level0_col19" class="col_heading level0 col19" >Status</th>
#       <th id="T_7df61_level0_col20" class="col_heading level0 col20" >Age_in_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7df61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7df61_row0_col0" class="data row0 col0" >2003</td>
#       <td id="T_7df61_row0_col1" class="data row0 col1" >1785</td>
#       <td id="T_7df61_row0_col2" class="data row0 col2" >D-penicillamine</td>
#       <td id="T_7df61_row0_col3" class="data row0 col3" >12779</td>
#       <td id="T_7df61_row0_col4" class="data row0 col4" >M</td>
#       <td id="T_7df61_row0_col5" class="data row0 col5" >N</td>
#       <td id="T_7df61_row0_col6" class="data row0 col6" >N</td>
#       <td id="T_7df61_row0_col7" class="data row0 col7" >N</td>
#       <td id="T_7df61_row0_col8" class="data row0 col8" >N</td>
#       <td id="T_7df61_row0_col9" class="data row0 col9" >2.100000</td>
#       <td id="T_7df61_row0_col10" class="data row0 col10" >442.000000</td>
#       <td id="T_7df61_row0_col11" class="data row0 col11" >3.630000</td>
#       <td id="T_7df61_row0_col12" class="data row0 col12" >177.000000</td>
#       <td id="T_7df61_row0_col13" class="data row0 col13" >1877.000000</td>
#       <td id="T_7df61_row0_col14" class="data row0 col14" >182.900000</td>
#       <td id="T_7df61_row0_col15" class="data row0 col15" >118.000000</td>
#       <td id="T_7df61_row0_col16" class="data row0 col16" >231.000000</td>
#       <td id="T_7df61_row0_col17" class="data row0 col17" >10.300000</td>
#       <td id="T_7df61_row0_col18" class="data row0 col18" >2.000000</td>
#       <td id="T_7df61_row0_col19" class="data row0 col19" >C</td>
#       <td id="T_7df61_row0_col20" class="data row0 col20" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7df61_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7df61_row1_col0" class="data row1 col0" >367</td>
#       <td id="T_7df61_row1_col1" class="data row1 col1" >3092</td>
#       <td id="T_7df61_row1_col2" class="data row1 col2" >D-penicillamine</td>
#       <td id="T_7df61_row1_col3" class="data row1 col3" >14872</td>
#       <td id="T_7df61_row1_col4" class="data row1 col4" >F</td>
#       <td id="T_7df61_row1_col5" class="data row1 col5" >N</td>
#       <td id="T_7df61_row1_col6" class="data row1 col6" >N</td>
#       <td id="T_7df61_row1_col7" class="data row1 col7" >N</td>
#       <td id="T_7df61_row1_col8" class="data row1 col8" >N</td>
#       <td id="T_7df61_row1_col9" class="data row1 col9" >0.800000</td>
#       <td id="T_7df61_row1_col10" class="data row1 col10" >315.000000</td>
#       <td id="T_7df61_row1_col11" class="data row1 col11" >4.010000</td>
#       <td id="T_7df61_row1_col12" class="data row1 col12" >14.000000</td>
#       <td id="T_7df61_row1_col13" class="data row1 col13" >1840.000000</td>
#       <td id="T_7df61_row1_col14" class="data row1 col14" >170.500000</td>
#       <td id="T_7df61_row1_col15" class="data row1 col

# %% [markdown]
# #### Thrombocytopenia Indicator
# - Thrombocytopenia Indicator is a binary measure.
# - It flags low platelet counts in blood.
# - Presence (1) indicates thrombocytopenia.
# - Absence (0) denotes normal platelet levels.
# - Useful for health assessments.

# %%
threshold_platelets = 150
df['thrombocytopenia'] = np.where(df['Platelets'] < threshold_platelets, 1, 0)
test_df['thrombocytopenia'] = np.where(test_df['Platelets'] < threshold_platelets, 1, 0)

# %% [markdown]
# #### Elevated Alkaline Phosphatase Indicator:
# Creating a binary indicator for elevated alkaline phosphatase based on a threshold.

# %%
threshold_alk_phos_upper = 147  # Upper limit of normal range
threshold_alk_phos_lower = 44   # Lower limit of normal range

df['elevated_alk_phos'] = np.where((df['Alk_Phos'] > threshold_alk_phos_upper) | (df['Alk_Phos'] < threshold_alk_phos_lower), 1, 0)
test_df['elevated_alk_phos'] = np.where((test_df['Alk_Phos'] > threshold_alk_phos_upper) | (test_df['Alk_Phos'] < threshold_alk_phos_lower), 1, 0)

# %% [markdown]
# #### Normal copper levels

# %%
normal_copper_range = (62, 140)

df['normal_copper'] = np.where((df['Copper'] >= normal_copper_range[0]) & (df['Copper'] <= normal_copper_range[1]), 1, 0)
test_df['normal_copper'] = np.where((test_df['Copper'] >= normal_copper_range[0]) & (test_df['Copper'] <= normal_copper_range[1]), 1, 0)

# %% [markdown]
# #### Normal Albumin Range is between  (3.4, 5.4)

# %%
normal_albumin_range = (3.4, 5.4)

df['normal_albumin'] = np.where((df['Albumin'] >= normal_albumin_range[0]) & (df['Albumin'] <= normal_albumin_range[1]), 1, 0)

test_df['normal_albumin'] = np.where((test_df['Albumin'] >= normal_albumin_range[0]) & (test_df['Albumin'] <= normal_albumin_range[1]), 1, 0)

# %% [markdown]
# #### Normal bilirubin levels
# Normal bilirubin levels depend on age, gender, and health. For adults, normal levels are usually between 0.2 and 1.2 milligrams per deciliter

# %%
normal_bilirubin_range = (0.2, 1.2)

df['normal_bilirubin'] = np.where((df['Bilirubin'] >= normal_bilirubin_range[0]) & (df['Bilirubin'] <= normal_bilirubin_range[1]), 1, 0)
test_df['normal_bilirubin'] = np.where((test_df['Bilirubin'] >= normal_bilirubin_range[0]) & (test_df['Bilirubin'] <= normal_bilirubin_range[1]), 1, 0)

# %% [markdown]
# # <a id="3"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">EDA </p>   </span></font></center>

# %% [markdown]
# # 📊 Exploratory Data Analysis

# %%
set_frame_style(df.head())
# Out:
# <style type="text/css">
# #T_95895 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_95895_row0_col0 {
#   background-color: #d2eeeb;
#   color: #000000;
# }
# #T_95895_row0_col1 {
#   background-color: #bae5dc;
#   color: #000000;
# }
# #T_95895_row0_col3, #T_95895_row0_col20, #T_95895_row0_col21, #T_95895_row0_col22, #T_95895_row0_col23, #T_95895_row0_col25, #T_95895_row1_col0, #T_95895_row1_col12, #T_95895_row1_col13, #T_95895_row1_col15, #T_95895_row1_col17, #T_95895_row1_col18, #T_95895_row1_col21, #T_95895_row1_col22, #T_95895_row1_col23, #T_95895_row2_col1, #T_95895_row2_col9, #T_95895_row2_col14, #T_95895_row2_col21, #T_95895_row2_col22, #T_95895_row2_col24, #T_95895_row3_col11, #T_95895_row3_col21, #T_95895_row3_col22, #T_95895_row3_col23, #T_95895_row3_col24, #T_95895_row3_col25, #T_95895_row4_col10, #T_95895_row4_col16, #T_95895_row4_col21, #T_95895_row4_col22, #T_95895_row4_col23 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_95895_row0_col9 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_95895_row0_col10 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_95895_row0_col11, #T_95895_row3_col1 {
#   background-color: #5dbd99;
#   color: #000000;
# }
# #T_95895_row0_col12, #T_95895_row0_col14, #T_95895_row0_col24, #T_95895_row1_col1, #T_95895_row1_col11, #T_95895_row1_col16, #T_95895_row1_col24, #T_95895_row1_col25, #T_95895_row2_col0, #T_95895_row2_col13, #T_95895_row2_col17, #T_95895_row2_col18, #T_95895_row2_col23, #T_95895_row2_col25, #T_95895_row3_col3, #T_95895_row3_col9, #T_95895_row3_col10, #T_95895_row3_col15, #T_95895_row3_col17, #T_95895_row3_col20, #T_95895_row4_col24, #T_95895_row4_col25 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_95895_row0_col13, #T_95895_row2_col16 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_95895_row0_col15 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_95895_row0_col16 {
#   background-color: #c4e9e1;
#   color: #000000;
# }
# #T_95895_row0_col17 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_95895_row0_col18, #T_95895_row3_col18 {
#   background-color: #aadfd3;
#   color: #000000;
# }
# #T_95895_row1_col3, #T_95895_row1_col20 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_95895_row1_col9 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_95895_row1_col10 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_95895_row1_col14 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_95895_row2_col3 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_95895_row2_col10, #T_95895_row3_col13 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_95895_row2_col11 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_95895_row2_col12 {
#   background-color: #9ad8ca;
#   color: #000000;
# }
# #T_95895_row2_col15 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_95895_row2_col20 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_95895_row3_col0 {
#   background-color: #b4e2d8;
#   color: #000000;
# }
# #T_95895_row3_col12, #T_95895_row4_col12 {
#   background-color: #c7eae3;
#   color: #000000;
# }
# #T_95895_row3_col14 {
#   background-color: #47b17e;
#   color: #f1f1f1;
# }
# #T_95895_row3_col16 {
#   background-color: #90d4c3;
#   color: #000000;
# }
# #T_95895_row4_col0 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_95895_row4_col1 {
#   background-color: #46b17c;
#   color: #f1f1f1;
# }
# #T_95895_row4_col3 {
#   background-color: #c2e8e0;
#   color: #000000;
# }
# #T_95895_row4_col9 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_95895_row4_col11 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_95895_row4_col13 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_95895_row4_col14 {
#   background-color: #339e60;
#   color: #f1f1f1;
# }
# #T_95895_row4_col15 {
#   background-color: #d3eeeb;
#   color: #000000;
# }
# #T_95895_row4_col17 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_95895_row4_col18 {
#   background-color: #37a266;
#   color: #f1f1f1;
# }
# #T_95895_row4_col20 {
#   background-color: #b7e4da;
#   color: #000000;
# }
# </style>
# <table id="T_95895">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95895_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_95895_level0_col1" class="col_heading level0 col1" >N_Days</th>
#       <th id="T_95895_level0_col2" class="col_heading level0 col2" >Drug</th>
#       <th id="T_95895_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_95895_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_95895_level0_col5" class="col_heading level0 col5" >Ascites</th>
#       <th id="T_95895_level0_col6" class="col_heading level0 col6" >Hepatomegaly</th>
#       <th id="T_95895_level0_col7" class="col_heading level0 col7" >Spiders</th>
#       <th id="T_95895_level0_col8" class="col_heading level0 col8" >Edema</th>
#       <th id="T_95895_level0_col9" class="col_heading level0 col9" >Bilirubin</th>
#       <th id="T_95895_level0_col10" class="col_heading level0 col10" >Cholesterol</th>
#       <th id="T_95895_level0_col11" class="col_heading level0 col11" >Albumin</th>
#       <th id="T_95895_level0_col12" class="col_heading level0 col12" >Copper</th>
#       <th id="T_95895_level0_col13" class="col_heading level0 col13" >Alk_Phos</th>
#       <th id="T_95895_level0_col14" class="col_heading level0 col14" >SGOT</th>
#       <th id="T_95895_level0_col15" class="col_heading level0 col15" >Tryglicerides</th>
#       <th id="T_95895_level0_col16" class="col_heading level0 col16" >Platelets</th>
#       <th id="T_95895_level0_col17" class="col_heading level0 col17" >Prothrombin</th>
#       <th id="T_95895_level0_col18" class="col_heading level0 col18" >Stage</th>
#       <th id="T_95895_level0_col19" class="col_heading level0 col19" >Status</th>
#       <th id="T_95895_level0_col20" class="col_heading level0 col20" >Age_in_year</th>
#       <th id="T_95895_level0_col21" class="col_heading level0 col21" >thrombocytopenia</th>
#       <th id="T_95895_level0_col22" class="col_heading level0 col22" >elevated_alk_phos</th>
#       <th id="T_95895_level0_col23" class="col_heading level0 col23" >normal_copper</th>
#       <th id="T_95895_level0_col24" class="col_heading level0 col24" >normal_albumin</th>
#       <th id="T_95895_level0_col25" class="col_heading level0 col25" >normal_bilirubin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95895_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95895_row0_col0" class="data row0 col0" >2003</td>
#       <td id="T_95895_row0_col1" class="data row0 col1" >1785</td>
#       <td id="T_95895_row0_col2" class="data row0 col2" >D-penicillamine</td>
#       <td id="T_95895_row0_col3" class="data row0 col3" >12779</td>
#       <td id="T_95895_row0_col4" class="data row0 col4" >M</td>
#       <td id="T_95895_row0_col5" class="data row0 col5" >N</td>
#       <td id="T_95895_row0_col6" class="data row0 col6" >N</td>
#       <td id="T_95895_row0_col7" class="data row0 col7" >N</td>
#       <td id="T_95895_row0_col8" class="data row0 col8" >N</td>
#       <td id="T_95895_row0_col9" class="data row0 col9" >2.100000</td>
#       <td id="T_95895_row0_col10" class="data row0 col10" >442.000000</td>
#       <td id="T_95895_row0_col11" class="data row0 col11" >3.630000</td>
#       <td id="T_95895_row0_col12" class="data row0 col12" >177.000000</td>
#       <td id="T_95895_row0_col13" class="data row0 col13" >1877.000000</td>
#       <td id="T_95895_row0_col14" class="data row0 col14" >182.900000</td>
#       <td id="T_95895_row0_col15" class="data row0 col15" >118.000000</td>
#       <td id="T_95895_row0_col16" class="data row0 col16" >231.000000</td>
#       <td id="T_95895_row0_col17" class="data row0 col17" >10.300000</td>
#       <td id="T_95895_row0_col18" class="data row0 col18" >2.000000</td>
#       <td id="T_95895_row0_col19" class="data row0 col19" >C</td>
#       <td id="T_95895_row0_col20" class="data row0 col20" >34</td>
#       <td id="T_95895_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_95895_row0_col22" class="data row0 col22" >1</td>
#       <td id="T_95895_row0_col23" class="data row0 col23" >0</td>
#       <td id

# %%
numeric_cols= ['N_Days',  'Age',  'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
       'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']
test_to_scale = test_df[numeric_cols]
train_to_scale = df[numeric_cols]
set_frame_style(train_to_scale.head(), 'Features with continuous values')
train_to_scale_original = original_df[numeric_cols]

# %% [markdown]
# ## <a id="3.1"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Distributions of Features </p>   </span></font></center>

# %% [markdown]
# # 📈 Feature Distribution

# %%
from plotly.subplots import make_subplots
import random
import plotly.graph_objects as go
columns = list(train_to_scale.columns)

ultra_light_colors = [
"#F0F8FF", "#F6F6F6", "#F0FFF0",  "#FAFAD2",  "#FFE4E1",  "#FFF5EE", "#F5FFFA",  "#F0FFFF","#FFFAF0",  "#F8F8FF"   
]
fig = make_subplots(rows=len(columns), cols=2)
count = 0
for row in range(int(len(columns))) : 
    random_col = f"RGB({random.randint(100, 255)}, {random.randint(100, 255)}, {random.randint(150, 255)})"
    fig.add_trace(go.Violin(y=syn_df[numeric_cols][columns[count]], x0 = columns[count], box_visible=True, line_color='black',
                               meanline_visible=True, fillcolor=random_col, opacity=0.6,), row=row + 1, col= 1)
    fig.add_trace(go.Violin(y= train_to_scale_original[columns[count]],x0 = columns[count], box_visible=True, line_color='black',
                               meanline_visible=True, fillcolor=random_col, opacity=0.6,), row=row + 1, col= 2)
 
    
    count +=1


fig.update_layout(height=2600, width=1000, title_text="Feature Distribution in Synthetic (Left) vs Original Dataset (Right)",showlegend=False,paper_bgcolor= '#F5F5F5')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2659a838-8bbc-404f-9e62-721e7a6af680" class="plotly-graph-div" style="height:2600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2659a838-8bbc-404f-9e62-721e7a6af680")) {                    Plotly.newPlot(                        "2659a838-8bbc-404f-9e62-721e7a6af680",                        [{"box":{"visible":true},"fillcolor":"RGB(207, 209, 165)","line":{"color":"black"},"meanline":{"visible":true},"opacity":0.6,"x0":"N_Days","y":[999,2574,3428,2576,788,703,1300,1615,2050,2615,3581,1614,1847,1153,904,1212,1967,1592,1481,3358,3092,326,2363,1152,3577,799,1832,4467,2301,943,1882,3244,1882,3090,850,2168,1786,1455,334,1363,3170,4032,2835,1434,3913,994,1666,3820,1149,930,2157,2555,1776,4050,51,3445,1765,3458,552,2769,4453,2504,980,853,786,3395,2357,549,1447,732,597,2363,708,2105,1295,1967,3092,2419,1295,3098,769,1083,4467,2168,1785,1657,1418,1615,737,1701,2598,2891,1234,3933,1271,3099,850,1455,2576,1831,3707,943,1363,191,2050,1831,3358,2318,1321,1420,794,1690,3672,837,1349,786,2556,850,1657,3933,4523,1170,1191,1367,1412,4509,904,2294,2976,2576,1303,1250,2255,1293,3149,1433,3090,2583,3086,2297,3099,3395,2504,1908,1000,2255,3149,2224,1212,4190,4500,1978,1785,2386,2624,1447,4079,2574,1568,3422,4365,3336,1481,2504,1576,2990,762,1951,1420,2105,3839,3358,2357,3099,3428,2976,3149,974,994,930,2403,1978,2576,2419,1649,2022,1770,4032,999,3297,1776,1569,3672,1297,4500,3090,2713,1569,2556,3933,1282,77,3358,837,1197,3098,4039,1302,943,1447,304,1690,1487,77,2365,2170,321,1657,1725,971,769,1077,4509,1785,3468,2350,1677,1434,4032,1657,597,1363,1216,3098,385,2657,2576,1487,1945,1408,769,1216,1444,2556,1216,1702,1030,1408,3244,3581,1234,1832,994,179,1978,708,1882,1360,3839,2050,1525,1216,1682,788,877,4509,890,1165,2891,2330,1783,939,334,216,4556,735,2449,1932,1250,1701,2576,980,2224,3574,732,930,1455,3853,77,4190,799,1434,2386,223,3282,4509,3099,1967,3820,1012,3672,2452,1067,264,3255,994,786,71,4039,1435,3853,3255,552,1418,1420,1568,3099,732,4032,2350,1735,1434,673,797,2772,1434,2170,131,824,3823,1413,41,2443,2170,3422,51,1701,1420,1702,533,51,3839,3574,2615,1356,2835,2456,4127,2255,3992,2863,1215,1785,3458,1469,1363,1831,1444,3090,2449,1874,2171,737,1783,1874,4453,2400,3092,2615,3823,51,901,2294,1433,3458,2976,2624,2456,2452,1558,890,1434,4509,2615,41,3090,797,4079,1542,3577,3239,2555,2466,2294,1363,321,2504,708,4523,2863,2797,3255,3222,1293,1363,1300,1978,2033,2563,2221,130,2224,1349,4127,2168,2689,2022,2615,2540,1301,1847,4523,2847,264,2556,769,388,1230,2365,1165,1012,1765,264,2081,1457,2055,2365,4039,1152,3574,3069,2255,1810,901,2297,1321,790,1250,4190,4365,2689,2443,4427,2176,2255,216,1462,750,2178,824,1785,1785,1925,2583,2224,1810,3820,2609,1295,2449,3059,1363,130,1785,1230,334,2157,1191,1216,3992,1765,1084,1321,853,1569,904,1235,3445,1434,3099,4039,4025,2863,2573,4050,1320,2419,1216,1690,597,2105,1360,2583,1487,1783,769,943,859,890,2105,4232,3853,3581,1492,2221,1765,3149,1350,1434,186,4191,1250,3458,4509,3282,1420,904,140,2272,4556,1212,3069,974,2769,1882,1320,110,1785,2456,1735,41,2847,853,1297,1614,1770,2835,3428,2363,2870,2624,1790,1408,3445,4509,4025,2221,2330,2105,3933,799,2272,1614,1525,1576,4795,1212,1350,2332,140,597,533,1783,3050,4079,2976,1770,3445,1657,304,3149,3069,750,1785,901,1191,3092,2468,1234,264,1302,3672,3839,2624,2598,1230,750,3395,2576,2363,1785,1216,216,1293,1558,1216,1360,737,2503,2255,1363,732,2419,3255,3913,1882,3584,2363,994,4232,1418,2504,788,788,4127,2504,1321,2573,3611,2624,1790,1434,4365,3149,1230,1701,3090,3707,3255,2863,549,2386,3913,4127,4050,2256,4127,3395,3933,1216,1457,1536,2178,3244,2573,326,1435,400,2241,4509,1420,1413,1300,1682,853,762,850,4196,762,179,4509,3244,611,2583,1786,3244,1783,3388,2598,4556,2294,1945,1356,216,1765,334,769,1321,1785,1925,2272,131,999,3445,419 ...

# %% [markdown]
# ### There are not much difference in the synthetically generated data and original data. Moreover, there are some characteristic features of both the distribution :
# > -   Tryglicerides has some outliers as q3 is 139 but the ax goes upto 598 : We need to use RobustScaler on it, that confines it in IQR
# > -   Similarly, Alk_Phos also has many outliers that needs to be rescaled using RobustScaler
# > -   Same for Cholestrol, Bilirubin and Prothrombin

# %%
set_frame_style(pd.DataFrame(df.Status.value_counts()), 'Data points per class', '15px')
# Out:
# <style type="text/css">
# #T_453de caption {
#   color: Brown;
#   font-size: 15px;
#   font-weight: bold;
# }
# #T_453de_row0_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_453de_row1_col0 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_453de_row2_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_453de">
#   <caption>Data points per class</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_453de_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Status</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_453de_level0_row0" class="row_heading level0 row0" >C</th>
#       <td id="T_453de_row0_col0" class="data row0 col0" >5112</td>
#     </tr>
#     <tr>
#       <th id="T_453de_level0_row1" class="row_heading level0 row1" >D</th>
#       <td id="T_453de_row1_col0" class="data row1 col0" >2776</td>
#     </tr>
#     <tr>
#       <th id="T_453de_level0_row2" class="row_heading level0 row2" >CL</th>
#       <td id="T_453de_row2_col0" class="data row2 col0" >293</td>
#     </tr>
#   </tbody>
# </table>

# %%
classes = list(df.Status.unique())

ultra_light_colors = [
"#F0F8FF", "#F6F6F6", "#F0FFF0",  "#FAFAD2",  "#FFE4E1",  "#FFF5EE", "#F5FFFA",  "#F0FFFF","#FFFAF0",  "#F8F8FF"   
]
def col_per_class(col):
    fig = go.Figure()
    for clas in classes : 
        fig.add_trace(go.Violin(y = df[col][df['Status']== clas],   box_visible=True,
                            meanline_visible=True , x = df['Status'][df['Status'] == clas], name = clas ))
        fig.update_layout(title = f'Distribution for {col} for each class', plot_bgcolor = ultra_light_colors[np.random.randint(1,10)],paper_bgcolor= '#F5F5F5', height=400,  
        width=1000 )
    return fig
for i in train_to_scale : 
    fig = col_per_class(i)
    fig.show()
# Out:
# <div>                            <div id="e3096ad0-e6e3-4eb9-808c-de41935bac83" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3096ad0-e6e3-4eb9-808c-de41935bac83")) {                    Plotly.newPlot(                        "e3096ad0-e6e3-4eb9-808c-de41935bac83",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="7da98764-f20b-4214-8f46-1b580e617c23" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7da98764-f20b-4214-8f46-1b580e617c23")) {                    Plotly.newPlot(                        "7da98764-f20b-4214-8f46-1b580e617c23",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="aa3acaf8-088b-441c-ad51-ed553fcd1c4f" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa3acaf8-088b-441c-ad51-ed553fcd1c4f")) {                    Plotly.newPlot(                        "aa3acaf8-088b-441c-ad51-ed553fcd1c4f",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="ce744985-6d80-44b2-8d07-34c0b6369b10" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce744985-6d80-44b2-8d07-34c0b6369b10")) {                    Plotly.newPlot(                        "ce744985-6d80-44b2-8d07-34c0b6369b10",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="f59d5ddd-3991-408b-a19b-a59c78936f6d" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f59d5ddd-3991-408b-a19b-a59c78936f6d")) {                    Plotly.newPlot(                        "f59d5ddd-3991-408b-a19b-a59c78936f6d",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="324b43a3-0d4a-4c16-b8e9-db78bc160b70" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("324b43a3-0d4a-4c16-b8e9-db78bc160b70")) {                    Plotly.newPlot(                        "324b43a3-0d4a-4c16-b8e9-db78bc160b70",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="cedb3d13-3717-4850-8305-a6356235e003" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cedb3d13-3717-4850-8305-a6356235e003")) {                    Plotly.newPlot(                        "cedb3d13-3717-4850-8305-a6356235e003",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="3502f91c-e738-474a-bee3-69d93160e9e6" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3502f91c-e738-474a-bee3-69d93160e9e6")) {                    Plotly.newPlot(                        "3502f91c-e738-474a-bee3-69d93160e9e6",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="4cf5291c-8d88-490d-9031-bd25551ea247" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cf5291c-8d88-490d-9031-bd25551ea247")) {                    Plotly.newPlot(                        "4cf5291c-8d88-490d-9031-bd25551ea247",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="ed38d6cc-cf88-4e7c-92cb-1820b4bc319f" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed38d6cc-cf88-4e7c-92cb-1820b4bc319f")) {                    Plotly.newPlot(                        "ed38d6cc-cf88-4e7c-92cb-1820b4bc319f",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...
# <div>                            <div id="de07e986-3354-41dc-94d2-6872f5468371" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de07e986-3354-41dc-94d2-6872f5468371")) {                    Plotly.newPlot(                        "de07e986-3354-41dc-94d2-6872f5468371",                        [{"box":{"visible":true},"meanline":{"visible":true},"name":"C","x":["C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C","C" ...

# %% [markdown]
# ## <a id="3.2"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Insights </p>   </span></font></center>

# %% [markdown]
# # 💡Insights

# %% [markdown]
# ### Number of data points per class are imbalanced :
# >- C : 4965
# >- D : 2665
# >- CL: 275
#
# ### N_days : Number of days between the registration and earlier of death, transplantation or study analysis time :
# > Class `D` is slighly on the lower side because most of them died before the study was closed. Similar is the situation with liver transpalnt individuals. Whereas for the `censored` patients, the study went on as most likely they survived or were not trackable.
# ### Age
# > The data shows that it mostly occures in 40+ years of age people, with death occuring mostly in higher aged people, and most of them get their liver transplants before 50
# ### Bilirubin : More serum bilirubin in blood, more is the complications with the liver
# > People who dies most probably had severe damage indicated by the higher level of bilirubin. The censored ones have less bilirubin levels indicating most of them were in control (not much damage). People who needed liver transplant also show higher levels
# ### Albumin : albumin production decreases due to impaired liver function.
# > This can be observed for the patient who didn't survived as their albumin levels dropped as compared to censored or the people with lover transplant
# ### Copper : Copper metabolism can be disrupted in Cirrosis, leading to its accumulation in the liver
# > This can be seen by observing the median of the copper content in patients who didn't survived
# ### Alk_Phos (Alkaline Phosphatase) : Its levels may elevate due to bile duct obstruction or cholestasis, common in cirrhosis
# > The median is quite high in `D` and `CL` patients
# ### Serum Glutamic Oxaloacetic Transaminase (SGOT) : SGOT levels may rise, indicating liver cell damage
# > The median is quite high in `D` and `CL` patients
# ### Triglycerides: Triglyceride levels may increase due to compromised liver function
# > The median is slightly high in `D` and `CL` patients
# ### Platelets: Platelet count often decreases as cirrhosis progresses
# > It is significanly less in the people who didn't survived
# ### Prothrombin Time (PT): Prothrombin time, a measure of blood clotting, can be prolonged in cirrhosis due to decreased synthesis of clotting factors by the liver
# > Again,significanly high in the people who didn't survived
#
# ### Based on above discussions, It seems like Patients in D category are very much differnt than C and CL class category patients. It'd be easier to differentiate D from C and CL. Challenging part is accurately determining the CL class patients and differentiating them from C class patients

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = train_to_scale.corr()

# Create a heatmap with masked upper triangle
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix (Lower Triangle)')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning:
#
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3

# %% [markdown]
# # <a id="4"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Preprocessing</p>   </span></font></center>

# %% [markdown]
# # ⚙️ Preprocessing

# %%
set_frame_style(df.head())
# Out:
# <style type="text/css">
# #T_ee698 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_ee698_row0_col0 {
#   background-color: #dfdfed;
#   color: #000000;
# }
# #T_ee698_row0_col1 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_ee698_row0_col3, #T_ee698_row0_col13, #T_ee698_row0_col20, #T_ee698_row0_col21, #T_ee698_row0_col22, #T_ee698_row0_col23, #T_ee698_row0_col25, #T_ee698_row1_col0, #T_ee698_row1_col12, #T_ee698_row1_col13, #T_ee698_row1_col15, #T_ee698_row1_col17, #T_ee698_row1_col18, #T_ee698_row1_col21, #T_ee698_row1_col22, #T_ee698_row1_col23, #T_ee698_row2_col1, #T_ee698_row2_col9, #T_ee698_row2_col14, #T_ee698_row2_col16, #T_ee698_row2_col21, #T_ee698_row2_col22, #T_ee698_row2_col24, #T_ee698_row3_col11, #T_ee698_row3_col21, #T_ee698_row3_col22, #T_ee698_row3_col23, #T_ee698_row3_col24, #T_ee698_row3_col25, #T_ee698_row4_col10, #T_ee698_row4_col16, #T_ee698_row4_col21, #T_ee698_row4_col22, #T_ee698_row4_col23 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_ee698_row0_col9 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_ee698_row0_col10 {
#   background-color: #5d3897;
#   color: #f1f1f1;
# }
# #T_ee698_row0_col11, #T_ee698_row3_col1 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_ee698_row0_col12, #T_ee698_row0_col14, #T_ee698_row0_col24, #T_ee698_row1_col1, #T_ee698_row1_col11, #T_ee698_row1_col16, #T_ee698_row1_col24, #T_ee698_row1_col25, #T_ee698_row2_col0, #T_ee698_row2_col13, #T_ee698_row2_col17, #T_ee698_row2_col18, #T_ee698_row2_col23, #T_ee698_row2_col25, #T_ee698_row3_col3, #T_ee698_row3_col9, #T_ee698_row3_col10, #T_ee698_row3_col15, #T_ee698_row3_col17, #T_ee698_row3_col20, #T_ee698_row4_col24, #T_ee698_row4_col25 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_ee698_row0_col15 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_ee698_row0_col16 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_ee698_row0_col17 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_ee698_row0_col18, #T_ee698_row3_col18 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_ee698_row1_col3, #T_ee698_row1_col20 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_ee698_row1_col9 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_ee698_row1_col10 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_ee698_row1_col14 {
#   background-color: #54278f;
#   color: #f1f1f1;
# }
# #T_ee698_row2_col3 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_ee698_row2_col10, #T_ee698_row3_col13 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_ee698_row2_col11 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_ee698_row2_col12 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_ee698_row2_col15 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_ee698_row2_col20 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_ee698_row3_col0 {
#   background-color: #cccce4;
#   color: #000000;
# }
# #T_ee698_row3_col12, #T_ee698_row4_col12 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_ee698_row3_col14 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# #T_ee698_row3_col16 {
#   background-color: #b7b7d9;
#   color: #000000;
# }
# #T_ee698_row4_col0 {
#   background-color: #5e3a98;
#   color: #f1f1f1;
# }
# #T_ee698_row4_col1 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_ee698_row4_col3 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_ee698_row4_col9 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_ee698_row4_col11 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_ee698_row4_col13 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_ee698_row4_col14 {
#   background-color: #7669af;
#   color: #f1f1f1;
# }
# #T_ee698_row4_col15 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_ee698_row4_col17 {
#   background-color: #61409b;
#   color: #f1f1f1;
# }
# #T_ee698_row4_col18 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_ee698_row4_col20 {
#   background-color: #cecee5;
#   color: #000000;
# }
# </style>
# <table id="T_ee698">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee698_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_ee698_level0_col1" class="col_heading level0 col1" >N_Days</th>
#       <th id="T_ee698_level0_col2" class="col_heading level0 col2" >Drug</th>
#       <th id="T_ee698_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_ee698_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_ee698_level0_col5" class="col_heading level0 col5" >Ascites</th>
#       <th id="T_ee698_level0_col6" class="col_heading level0 col6" >Hepatomegaly</th>
#       <th id="T_ee698_level0_col7" class="col_heading level0 col7" >Spiders</th>
#       <th id="T_ee698_level0_col8" class="col_heading level0 col8" >Edema</th>
#       <th id="T_ee698_level0_col9" class="col_heading level0 col9" >Bilirubin</th>
#       <th id="T_ee698_level0_col10" class="col_heading level0 col10" >Cholesterol</th>
#       <th id="T_ee698_level0_col11" class="col_heading level0 col11" >Albumin</th>
#       <th id="T_ee698_level0_col12" class="col_heading level0 col12" >Copper</th>
#       <th id="T_ee698_level0_col13" class="col_heading level0 col13" >Alk_Phos</th>
#       <th id="T_ee698_level0_col14" class="col_heading level0 col14" >SGOT</th>
#       <th id="T_ee698_level0_col15" class="col_heading level0 col15" >Tryglicerides</th>
#       <th id="T_ee698_level0_col16" class="col_heading level0 col16" >Platelets</th>
#       <th id="T_ee698_level0_col17" class="col_heading level0 col17" >Prothrombin</th>
#       <th id="T_ee698_level0_col18" class="col_heading level0 col18" >Stage</th>
#       <th id="T_ee698_level0_col19" class="col_heading level0 col19" >Status</th>
#       <th id="T_ee698_level0_col20" class="col_heading level0 col20" >Age_in_year</th>
#       <th id="T_ee698_level0_col21" class="col_heading level0 col21" >thrombocytopenia</th>
#       <th id="T_ee698_level0_col22" class="col_heading level0 col22" >elevated_alk_phos</th>
#       <th id="T_ee698_level0_col23" class="col_heading level0 col23" >normal_copper</th>
#       <th id="T_ee698_level0_col24" class="col_heading level0 col24" >normal_albumin</th>
#       <th id="T_ee698_level0_col25" class="col_heading level0 col25" >normal_bilirubin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee698_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee698_row0_col0" class="data row0 col0" >2003</td>
#       <td id="T_ee698_row0_col1" class="data row0 col1" >1785</td>
#       <td id="T_ee698_row0_col2" class="data row0 col2" >D-penicillamine</td>
#       <td id="T_ee698_row0_col3" class="data row0 col3" >12779</td>
#       <td id="T_ee698_row0_col4" class="data row0 col4" >M</td>
#       <td id="T_ee698_row0_col5" class="data row0 col5" >N</td>
#       <td id="T_ee698_row0_col6" class="data row0 col6" >N</td>
#       <td id="T_ee698_row0_col7" class="data row0 col7" >N</td>
#       <td id="T_ee698_row0_col8" class="data row0 col8" >N</td>
#       <td id="T_ee698_row0_col9" class="data row0 col9" >2.100000</td>
#       <td id="T_ee698_row0_col10" class="data row0 col10" >442.000000</td>
#       <td id="T_ee698_row0_col11" class="data row0 col11" >3.630000</td>
#       <td id="T_ee698_row0_col12" class="data row0 col12" >177.000000</td>
#       <td id="T_ee698_row0_col13" class="data row0 col13" >1877.000000</td>
#       <td id="T_ee698_row0_col14" class="data row0 col14" >182.900000</td>
#       <td id="T_ee698_row0_col15" class="data row0 col15" >118.000000</td>
#       <td id="T_ee698_row0_col16" class="data row0 col16" >231.000000</td>
#       <td id="T_ee698_row0_col17" class="data row0 col17" >10.300000</td>
#       <td id="T_ee698_row0_col18" class="data row0 col18" >2.000000</td>
#       <td id="T_ee698_row0_col19" class="data row0 col19" >C</td>
#       <td id="T_ee698_row0_col20" class="data row0 col20" >34</td>
#       <td id="T_ee698_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_ee698_row0_col22" class="data row0 col22" >1</td>
#       <td id="T_ee698_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_ee698_row0_col24" class="data row0 col24" >1</

# %% [markdown]
# # <a id="4.1"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:200%;text-align:center;border-radius:5px 5px;padding : 2px">Robustscaler</p>   </span></font></center>
# > ###  It focuses only on the IQR for scaling unless specified/changed

# %% [markdown]
# # Robustscaler

# %%
from sklearn.preprocessing import RobustScaler

sc = RobustScaler()


scaled_train = pd.DataFrame(sc.fit_transform(train_to_scale),columns = train_to_scale.columns)
scaled_test = pd.DataFrame(sc.transform(test_to_scale),columns = test_to_scale.columns)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
set_frame_style(scaled_train.head())
# Out:
# <style type="text/css">
# #T_f4a80 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_f4a80_row0_col0 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_f4a80_row0_col1, #T_f4a80_row1_col5, #T_f4a80_row1_col6, #T_f4a80_row1_col8, #T_f4a80_row1_col10, #T_f4a80_row2_col0, #T_f4a80_row2_col2, #T_f4a80_row2_col7, #T_f4a80_row3_col4, #T_f4a80_row4_col3, #T_f4a80_row4_col9 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_f4a80_row0_col2 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_f4a80_row0_col3 {
#   background-color: #bb3d02;
#   color: #f1f1f1;
# }
# #T_f4a80_row0_col4, #T_f4a80_row3_col0 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_f4a80_row0_col5, #T_f4a80_row0_col7, #T_f4a80_row1_col0, #T_f4a80_row1_col4, #T_f4a80_row1_col9, #T_f4a80_row2_col6, #T_f4a80_row2_col10, #T_f4a80_row3_col1, #T_f4a80_row3_col2, #T_f4a80_row3_col3, #T_f4a80_row3_col8, #T_f4a80_row3_col10 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f4a80_row0_col6, #T_f4a80_row2_col9 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_f4a80_row0_col8 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_f4a80_row0_col9 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_f4a80_row0_col10 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_f4a80_row1_col1 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_f4a80_row1_col2 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_f4a80_row1_col3 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_f4a80_row1_col7 {
#   background-color: #a63603;
#   color: #f1f1f1;
# }
# #T_f4a80_row2_col1 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_f4a80_row2_col3, #T_f4a80_row3_col6 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_f4a80_row2_col4 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_f4a80_row2_col5 {
#   background-color: #fdaf6c;
#   color: #000000;
# }
# #T_f4a80_row2_col8 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_f4a80_row3_col5, #T_f4a80_row4_col5 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_f4a80_row3_col7 {
#   background-color: #f36f1a;
#   color: #f1f1f1;
# }
# #T_f4a80_row3_col9 {
#   background-color: #fda863;
#   color: #000000;
# }
# #T_f4a80_row4_col0 {
#   background-color: #f36e19;
#   color: #f1f1f1;
# }
# #T_f4a80_row4_col1 {
#   background-color: #fdc997;
#   color: #000000;
# }
# #T_f4a80_row4_col2 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_f4a80_row4_col4 {
#   background-color: #8a2b04;
#   color: #f1f1f1;
# }
# #T_f4a80_row4_col6 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_f4a80_row4_col7 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
# }
# #T_f4a80_row4_col8 {
#   background-color: #fdd6ae;
#   color: #000000;
# }
# #T_f4a80_row4_col10 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f4a80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4a80_level0_col0" class="col_heading level0 col0" >N_Days</th>
#       <th id="T_f4a80_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_f4a80_level0_col2" class="col_heading level0 col2" >Bilirubin</th>
#       <th id="T_f4a80_level0_col3" class="col_heading level0 col3" >Cholesterol</th>
#       <th id="T_f4a80_level0_col4" class="col_heading level0 col4" >Albumin</th>
#       <th id="T_f4a80_level0_col5" class="col_heading level0 col5" >Copper</th>
#       <th id="T_f4a80_level0_col6" class="col_heading level0 col6" >Alk_Phos</th>
#       <th id="T_f4a80_level0_col7" class="col_heading level0 col7" >SGOT</th>
#       <th id="T_f4a80_level0_col8" class="col_heading level0 col8" >Tryglicerides</th>
#       <th id="T_f4a80_level0_col9" class="col_heading level0 col9" >Platelets</th>
#       <th id="T_f4a80_level0_col10" class="col_heading level0 col10" >Prothrombin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4a80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4a80_row0_col0" class="data row0 col0" >-0.031528</td>
#       <td id="T_f4a80_row0_col1" class="data row0 col1" >-1.158904</td>
#       <td id="T_f4a80_row0_col2" class="data row0 col2" >0.434783</td>
#       <td id="T_f4a80_row0_col3" class="data row0 col3" >0.993056</td>
#       <td id="T_f4a80_row0_col4" class="data row0 col4" >0.119048</td>
#       <td id="T_f4a80_row0_col5" class="data row0 col5" >1.809524</td>
#       <td id="T_f4a80_row0_col6" class="data row0 col6" >0.680352</td>
#       <td id="T_f4a80_row0_col7" class="data row0 col7" >1.200000</td>
#       <td id="T_f4a80_row0_col8" class="data row0 col8" >0.254545</td>
#       <td id="T_f4a80_row0_col9" class="data row0 col9" >-0.320755</td>
#       <td id="T_f4a80_row0_col10" class="data row0 col10" >-0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_f4a80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4a80_row1_col0" class="data row1 col0" >0.864291</td>
#       <td id="T_f4a80_row1_col1" class="data row1 col1" >-0.749315</td>
#       <td id="T_f4a80_row1_col2" class="data row1 col2" >-0.130435</td>
#       <td id="T_f4a80_row1_col3" class="data row1 col3" >0.111111</td>
#       <td id="T_f4a80_row1_col4" class="data row1 col4" >1.023810</td>
#       <td id="T_f4a80_row1_col5" class="data row1 col5" >-0.777778</td>
#       <td id="T_f4a80_row1_col6" class="data row1 col6" >0.644184</td>
#       <td id="T_f4a80_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_f4a80_row1_col8" class="data row1 col8" >-0.600000</td>
#       <td id="T_f4a80_row1_col9" class="data row1 col9" >1.698113</td>
#       <td id="T_f4a80_row1_col10" class="data row1 col10" >-0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_f4a80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4a80_row2_col0" class="data row2 col0" >-0.409184</td>
#       <td id="T_f4a80_row2_col1" class="data row2 col1" >-1.010959</td>
#       <td id="T_f4a80_row2_col2" class="data row2 col2" >-0.173913</td>
#       <td id="T_f4a80_row2_col3" class="data row2 col3" >-0.298611</td>
#       <td id="T_f4a80_row2_col4" class="data row2 col4" >-0.500000</td>
#       <td id="T_f4a80_row2_col5" class="data row2 col5" >0.190476</td>
#       <td id="T_f4a80_row2_col6" class="data row2 col6" >5.958944</td>
#       <td id="T_f4a80_row2_col7" class="data row2 col7" >-0.375000</td>
#       <td id="T_f4a80_row2_col8" class="data row2 col8" >0.072727</td>
#       <td id="T_f4a80_row2_col9" class="data row2 col9" >-1.056604</td>
#       <td id="T_f4a80_row2_col10" class="data row2 col10" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_f4a80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4a80_row3_col0" class="data row3 col0" >0.267306</td>
#       <td id="T_f4a80_row3_col1" class="data row3 col1" >0.428571</td>
#       <td id="T_f4a80_row3_col2" class="data row3 col2" >0.521739</td>
#       <td id="T_f4a80_row3_col3" class="data row3 col3" >1.298611</td>
#       <td id="T_f4a80_row3_col4" class="data row3 col4" >-0.904762</td>
#       <td id="T_f4a80_row3_col5" class="data row3 col5" >-0.095238</td>
#       <td id="T_f4a80_row3_col6" class="data row3 col6" >1.070381</td>
#       <td id="T_f4a80_row3_col7" class="data row3 col7" >0.575000</td>
#       <td id="T_f4a80_row3_col8" class="data row3 col8" >1.327273</td>
#       <td id="T_f4a80_row3_col9" class="data row3 col9" >0.028302</td>
#       <td id="T_f4a80_row3_col10" class="data row3 col10" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_f4a80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4a80_row4_col0" class="data row4 col0" >0.364633</td>
#       <td id="T_f4a80_row4_col1" class="data row4 col1" >-0.722505</td>
#       <td id="T_f4a80_row4_col2" class="data row4 col2" >-0.086957</td>
#       <td id="T_f4a80_row4_col3" class="data row4 col3" >-0.437500</td>
#       <td id="T_f4a80_row4_col4" class="data row4 col4" >0.952381</td>
#       <td id="T_f4a80_row4_col5" class="data row4 col5" >-0.095238</td>
#       <td id="T_f4a80_row4_col6" class="data row4 col6" >0.945259</td>
#       <td id="T_f4a80_row4_col7" class="data row4 col7" >0.700000</td>
#       <td id="T_f4a80_row4_col8" class="data row4 col8" >-0.181818</td>
#       <td id=

# %%
train_ohe = df.drop(numeric_cols, axis =1)
train_to_ohe = train_ohe.drop(['id','Age_in_year','Status'], axis =1)
test_ohe = test_df.drop(numeric_cols, axis =1)
test_to_ohe = test_ohe.drop(['id'],axis =1)
set_frame_style(train_to_ohe.head())
# Out:
# <style type="text/css">
# #T_80f7f caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_80f7f_row0_col6, #T_80f7f_row3_col6 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_80f7f_row0_col7, #T_80f7f_row0_col8, #T_80f7f_row0_col9, #T_80f7f_row0_col11, #T_80f7f_row1_col6, #T_80f7f_row1_col7, #T_80f7f_row1_col8, #T_80f7f_row1_col9, #T_80f7f_row2_col7, #T_80f7f_row2_col8, #T_80f7f_row2_col10, #T_80f7f_row3_col7, #T_80f7f_row3_col8, #T_80f7f_row3_col9, #T_80f7f_row3_col10, #T_80f7f_row3_col11, #T_80f7f_row4_col7, #T_80f7f_row4_col8, #T_80f7f_row4_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_80f7f_row0_col10, #T_80f7f_row1_col10, #T_80f7f_row1_col11, #T_80f7f_row2_col6, #T_80f7f_row2_col9, #T_80f7f_row2_col11, #T_80f7f_row4_col10, #T_80f7f_row4_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_80f7f_row4_col6 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80f7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80f7f_level0_col0" class="col_heading level0 col0" >Drug</th>
#       <th id="T_80f7f_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_80f7f_level0_col2" class="col_heading level0 col2" >Ascites</th>
#       <th id="T_80f7f_level0_col3" class="col_heading level0 col3" >Hepatomegaly</th>
#       <th id="T_80f7f_level0_col4" class="col_heading level0 col4" >Spiders</th>
#       <th id="T_80f7f_level0_col5" class="col_heading level0 col5" >Edema</th>
#       <th id="T_80f7f_level0_col6" class="col_heading level0 col6" >Stage</th>
#       <th id="T_80f7f_level0_col7" class="col_heading level0 col7" >thrombocytopenia</th>
#       <th id="T_80f7f_level0_col8" class="col_heading level0 col8" >elevated_alk_phos</th>
#       <th id="T_80f7f_level0_col9" class="col_heading level0 col9" >normal_copper</th>
#       <th id="T_80f7f_level0_col10" class="col_heading level0 col10" >normal_albumin</th>
#       <th id="T_80f7f_level0_col11" class="col_heading level0 col11" >normal_bilirubin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80f7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80f7f_row0_col0" class="data row0 col0" >D-penicillamine</td>
#       <td id="T_80f7f_row0_col1" class="data row0 col1" >M</td>
#       <td id="T_80f7f_row0_col2" class="data row0 col2" >N</td>
#       <td id="T_80f7f_row0_col3" class="data row0 col3" >N</td>
#       <td id="T_80f7f_row0_col4" class="data row0 col4" >N</td>
#       <td id="T_80f7f_row0_col5" class="data row0 col5" >N</td>
#       <td id="T_80f7f_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_80f7f_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_80f7f_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_80f7f_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_80f7f_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_80f7f_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_80f7f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80f7f_row1_col0" class="data row1 col0" >D-penicillamine</td>
#       <td id="T_80f7f_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_80f7f_row1_col2" class="data row1 col2" >N</td>
#       <td id="T_80f7f_row1_col3" class="data row1 col3" >N</td>
#       <td id="T_80f7f_row1_col4" class="data row1 col4" >N</td>
#       <td id="T_80f7f_row1_col5" class="data row1 col5" >N</td>
#       <td id="T_80f7f_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_80f7f_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_80f7f_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_80f7f_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_80f7f_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_80f7f_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_80f7f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80f7f_row2_col0" class="data row2 col0" >D-penicillamine</td>
#       <td id="T_80f7f_row2_col1" class="data row2 col1" >F</td>
#       <td id="T_80f7f_row2_col2" class="data row2 col2" >N</td>
#       <td id="T_80f7f_row2_col3" class="data row2 col3" >Y</td>
#       <td id="T_80f7f_row2_col4" class="data row2 col4" >N</td>
#       <td id="T_80f7f_row2_col5" class="data row2 col5" >N</td>
#       <td id="T_80f7f_row2_col6" class="data row2 col6" >4.000000</td>
#       <td id="T_80f7f_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_80f7f_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_80f7f_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_80f7f_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_80f7f_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_80f7f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80f7f_row3_col0" class="data row3 col0" >Placebo</td>
#       <td id="T_80f7f_row3_col1" class="data row3 col1" >M</td>
#       <td id="T_80f7f_row3_col2" class="data row3 col2" >N</td>
#       <td id="T_80f7f_row3_col3" class="data row3 col3" >Y</td>
#       <td id="T_80f7f_row3_col4" class="data row3 col4" >N</td>
#       <td id="T_80f7f_row3_col5" class="data row3 col5" >N</td>
#       <td id="T_80f7f_row3_col6" class="data row3 col6" >2.000000</td>
#       <td id="T_80f7f_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_80f7f_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_80f7f_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_80f7f_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_80f7f_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_80f7f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80f7f_row4_col0" class="data row4 col0" >D-penicillamine</td>
#       <td id="T_80f7f_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_80f7f_row4_col2" class="data row4 col2" >N</td>
#       <td id="T_80f7f_row4_col3" class="data row4 col3" >Y</td>
#       <td id="T_80f7f_row4_col4" class="data row4 col4" >Y</td>
#       <td id="T_80f7f_row4_col5" class="data row4 col5" >N</td>
#       <td id="T_80f7f_row4_col6" class="data row4 col6" >3.000000</td>
#       <td id="T_80f7f_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_80f7f_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_80f7f_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_80f7f_row4_col10" class="data row4 col10" >1</td>
#       <td id="T_80f7f_row4_col11" class="data row4 col11" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
set_frame_style(test_to_ohe.head())
# Out:
# <style type="text/css">
# #T_820fa caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_820fa_row0_col6, #T_820fa_row1_col6, #T_820fa_row3_col6 {
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_820fa_row0_col7, #T_820fa_row0_col8, #T_820fa_row0_col10, #T_820fa_row1_col7, #T_820fa_row1_col8, #T_820fa_row2_col7, #T_820fa_row2_col8, #T_820fa_row2_col9, #T_820fa_row2_col10, #T_820fa_row2_col11, #T_820fa_row3_col7, #T_820fa_row3_col8, #T_820fa_row3_col9, #T_820fa_row4_col6, #T_820fa_row4_col7, #T_820fa_row4_col8, #T_820fa_row4_col10, #T_820fa_row4_col11 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_820fa_row0_col9, #T_820fa_row0_col11, #T_820fa_row1_col9, #T_820fa_row1_col10, #T_820fa_row1_col11, #T_820fa_row2_col6, #T_820fa_row3_col10, #T_820fa_row3_col11, #T_820fa_row4_col9 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_820fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_820fa_level0_col0" class="col_heading level0 col0" >Drug</th>
#       <th id="T_820fa_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_820fa_level0_col2" class="col_heading level0 col2" >Ascites</th>
#       <th id="T_820fa_level0_col3" class="col_heading level0 col3" >Hepatomegaly</th>
#       <th id="T_820fa_level0_col4" class="col_heading level0 col4" >Spiders</th>
#       <th id="T_820fa_level0_col5" class="col_heading level0 col5" >Edema</th>
#       <th id="T_820fa_level0_col6" class="col_heading level0 col6" >Stage</th>
#       <th id="T_820fa_level0_col7" class="col_heading level0 col7" >thrombocytopenia</th>
#       <th id="T_820fa_level0_col8" class="col_heading level0 col8" >elevated_alk_phos</th>
#       <th id="T_820fa_level0_col9" class="col_heading level0 col9" >normal_copper</th>
#       <th id="T_820fa_level0_col10" class="col_heading level0 col10" >normal_albumin</th>
#       <th id="T_820fa_level0_col11" class="col_heading level0 col11" >normal_bilirubin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_820fa_row0_col0" class="data row0 col0" >D-penicillamine</td>
#       <td id="T_820fa_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_820fa_row0_col2" class="data row0 col2" >N</td>
#       <td id="T_820fa_row0_col3" class="data row0 col3" >Y</td>
#       <td id="T_820fa_row0_col4" class="data row0 col4" >N</td>
#       <td id="T_820fa_row0_col5" class="data row0 col5" >N</td>
#       <td id="T_820fa_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_820fa_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_820fa_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_820fa_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_820fa_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_820fa_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_820fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_820fa_row1_col0" class="data row1 col0" >D-penicillamine</td>
#       <td id="T_820fa_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_820fa_row1_col2" class="data row1 col2" >N</td>
#       <td id="T_820fa_row1_col3" class="data row1 col3" >N</td>
#       <td id="T_820fa_row1_col4" class="data row1 col4" >N</td>
#       <td id="T_820fa_row1_col5" class="data row1 col5" >N</td>
#       <td id="T_820fa_row1_col6" class="data row1 col6" >2.000000</td>
#       <td id="T_820fa_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_820fa_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_820fa_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_820fa_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_820fa_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_820fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_820fa_row2_col0" class="data row2 col0" >Placebo</td>
#       <td id="T_820fa_row2_col1" class="data row2 col1" >F</td>
#       <td id="T_820fa_row2_col2" class="data row2 col2" >N</td>
#       <td id="T_820fa_row2_col3" class="data row2 col3" >Y</td>
#       <td id="T_820fa_row2_col4" class="data row2 col4" >N</td>
#       <td id="T_820fa_row2_col5" class="data row2 col5" >Y</td>
#       <td id="T_820fa_row2_col6" class="data row2 col6" >4.000000</td>
#       <td id="T_820fa_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_820fa_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_820fa_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_820fa_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_820fa_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_820fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_820fa_row3_col0" class="data row3 col0" >D-penicillamine</td>
#       <td id="T_820fa_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_820fa_row3_col2" class="data row3 col2" >N</td>
#       <td id="T_820fa_row3_col3" class="data row3 col3" >N</td>
#       <td id="T_820fa_row3_col4" class="data row3 col4" >N</td>
#       <td id="T_820fa_row3_col5" class="data row3 col5" >N</td>
#       <td id="T_820fa_row3_col6" class="data row3 col6" >2.000000</td>
#       <td id="T_820fa_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_820fa_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_820fa_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_820fa_row3_col10" class="data row3 col10" >1</td>
#       <td id="T_820fa_row3_col11" class="data row3 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_820fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_820fa_row4_col0" class="data row4 col0" >D-penicillamine</td>
#       <td id="T_820fa_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_820fa_row4_col2" class="data row4 col2" >N</td>
#       <td id="T_820fa_row4_col3" class="data row4 col3" >Y</td>
#       <td id="T_820fa_row4_col4" class="data row4 col4" >N</td>
#       <td id="T_820fa_row4_col5" class="data row4 col5" >N</td>
#       <td id="T_820fa_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_820fa_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_820fa_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_820fa_row4_col9" class="data row4 col9" >1</td>
#       <td id="T_820fa_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_820fa_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## <a id="4.2"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:200%;text-align:center;border-radius:5px 5px;padding : 2px">One-hot encoding the categorical columns</p>   </span></font></center>

# %% [markdown]
# # One-hot Encoding

# %%
ohe_train = pd.get_dummies(train_to_ohe, columns =train_to_ohe.columns )
ohe_test  = pd.get_dummies(test_to_ohe, columns = train_to_ohe.columns)
ohe_train = ohe_train.replace({True: 1, False: 0})
ohe_test = ohe_test.replace({True: 1, False: 0})
set_frame_style(ohe_train.head())
# Out:
# <style type="text/css">
# #T_452f7 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_452f7_row0_col0, #T_452f7_row0_col3, #T_452f7_row0_col6, #T_452f7_row0_col8, #T_452f7_row0_col14, #T_452f7_row0_col20, #T_452f7_row0_col23, #T_452f7_row0_col24, #T_452f7_row1_col0, #T_452f7_row1_col2, #T_452f7_row1_col6, #T_452f7_row1_col8, #T_452f7_row1_col13, #T_452f7_row1_col20, #T_452f7_row1_col23, #T_452f7_row1_col25, #T_452f7_row2_col0, #T_452f7_row2_col2, #T_452f7_row2_col7, #T_452f7_row2_col8, #T_452f7_row2_col16, #T_452f7_row2_col21, #T_452f7_row2_col22, #T_452f7_row2_col25, #T_452f7_row3_col1, #T_452f7_row3_col3, #T_452f7_row3_col7, #T_452f7_row3_col8, #T_452f7_row3_col14, #T_452f7_row3_col20, #T_452f7_row3_col22, #T_452f7_row3_col24, #T_452f7_row4_col0, #T_452f7_row4_col2, #T_452f7_row4_col7, #T_452f7_row4_col9, #T_452f7_row4_col15, #T_452f7_row4_col20, #T_452f7_row4_col23, #T_452f7_row4_col25 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_452f7_row0_col1, #T_452f7_row0_col2, #T_452f7_row0_col4, #T_452f7_row0_col5, #T_452f7_row0_col7, #T_452f7_row0_col9, #T_452f7_row0_col10, #T_452f7_row0_col11, #T_452f7_row0_col12, #T_452f7_row0_col13, #T_452f7_row0_col15, #T_452f7_row0_col16, #T_452f7_row0_col17, #T_452f7_row0_col18, #T_452f7_row0_col19, #T_452f7_row0_col21, #T_452f7_row0_col22, #T_452f7_row0_col25, #T_452f7_row1_col1, #T_452f7_row1_col3, #T_452f7_row1_col4, #T_452f7_row1_col5, #T_452f7_row1_col7, #T_452f7_row1_col9, #T_452f7_row1_col10, #T_452f7_row1_col11, #T_452f7_row1_col12, #T_452f7_row1_col14, #T_452f7_row1_col15, #T_452f7_row1_col16, #T_452f7_row1_col17, #T_452f7_row1_col18, #T_452f7_row1_col19, #T_452f7_row1_col21, #T_452f7_row1_col22, #T_452f7_row1_col24, #T_452f7_row2_col1, #T_452f7_row2_col3, #T_452f7_row2_col4, #T_452f7_row2_col5, #T_452f7_row2_col6, #T_452f7_row2_col9, #T_452f7_row2_col10, #T_452f7_row2_col11, #T_452f7_row2_col12, #T_452f7_row2_col13, #T_452f7_row2_col14, #T_452f7_row2_col15, #T_452f7_row2_col17, #T_452f7_row2_col18, #T_452f7_row2_col19, #T_452f7_row2_col20, #T_452f7_row2_col23, #T_452f7_row2_col24, #T_452f7_row3_col0, #T_452f7_row3_col2, #T_452f7_row3_col4, #T_452f7_row3_col5, #T_452f7_row3_col6, #T_452f7_row3_col9, #T_452f7_row3_col10, #T_452f7_row3_col11, #T_452f7_row3_col12, #T_452f7_row3_col13, #T_452f7_row3_col15, #T_452f7_row3_col16, #T_452f7_row3_col17, #T_452f7_row3_col18, #T_452f7_row3_col19, #T_452f7_row3_col21, #T_452f7_row3_col23, #T_452f7_row3_col25, #T_452f7_row4_col1, #T_452f7_row4_col3, #T_452f7_row4_col4, #T_452f7_row4_col5, #T_452f7_row4_col6, #T_452f7_row4_col8, #T_452f7_row4_col10, #T_452f7_row4_col11, #T_452f7_row4_col12, #T_452f7_row4_col13, #T_452f7_row4_col14, #T_452f7_row4_col16, #T_452f7_row4_col17, #T_452f7_row4_col18, #T_452f7_row4_col19, #T_452f7_row4_col21, #T_452f7_row4_col22, #T_452f7_row4_col24 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# </style>
# <table id="T_452f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_452f7_level0_col0" class="col_heading level0 col0" >Drug_D-penicillamine</th>
#       <th id="T_452f7_level0_col1" class="col_heading level0 col1" >Drug_Placebo</th>
#       <th id="T_452f7_level0_col2" class="col_heading level0 col2" >Sex_F</th>
#       <th id="T_452f7_level0_col3" class="col_heading level0 col3" >Sex_M</th>
#       <th id="T_452f7_level0_col4" class="col_heading level0 col4" >Ascites_N</th>
#       <th id="T_452f7_level0_col5" class="col_heading level0 col5" >Ascites_Y</th>
#       <th id="T_452f7_level0_col6" class="col_heading level0 col6" >Hepatomegaly_N</th>
#       <th id="T_452f7_level0_col7" class="col_heading level0 col7" >Hepatomegaly_Y</th>
#       <th id="T_452f7_level0_col8" class="col_heading level0 col8" >Spiders_N</th>
#       <th id="T_452f7_level0_col9" class="col_heading level0 col9" >Spiders_Y</th>
#       <th id="T_452f7_level0_col10" class="col_heading level0 col10" >Edema_N</th>
#       <th id="T_452f7_level0_col11" class="col_heading level0 col11" >Edema_S</th>
#       <th id="T_452f7_level0_col12" class="col_heading level0 col12" >Edema_Y</th>
#       <th id="T_452f7_level0_col13" class="col_heading level0 col13" >Stage_1.0</th>
#       <th id="T_452f7_level0_col14" class="col_heading level0 col14" >Stage_2.0</th>
#       <th id="T_452f7_level0_col15" class="col_heading level0 col15" >Stage_3.0</th>
#       <th id="T_452f7_level0_col16" class="col_heading level0 col16" >Stage_4.0</th>
#       <th id="T_452f7_level0_col17" class="col_heading level0 col17" >thrombocytopenia_0</th>
#       <th id="T_452f7_level0_col18" class="col_heading level0 col18" >thrombocytopenia_1</th>
#       <th id="T_452f7_level0_col19" class="col_heading level0 col19" >elevated_alk_phos_1</th>
#       <th id="T_452f7_level0_col20" class="col_heading level0 col20" >normal_copper_0</th>
#       <th id="T_452f7_level0_col21" class="col_heading level0 col21" >normal_copper_1</th>
#       <th id="T_452f7_level0_col22" class="col_heading level0 col22" >normal_albumin_0</th>
#       <th id="T_452f7_level0_col23" class="col_heading level0 col23" >normal_albumin_1</th>
#       <th id="T_452f7_level0_col24" class="col_heading level0 col24" >normal_bilirubin_0</th>
#       <th id="T_452f7_level0_col25" class="col_heading level0 col25" >normal_bilirubin_1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_452f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_452f7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_452f7_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_452f7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_452f7_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_452f7_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_452f7_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_452f7_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_452f7_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_452f7_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_452f7_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_452f7_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_452f7_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_452f7_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_452f7_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_452f7_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_452f7_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_452f7_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_452f7_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_452f7_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_452f7_row0_col19" class="data row0 col19" >1</td>
#       <td id="T_452f7_row0_col20" class="data row0 col20" >1</td>
#       <td id="T_452f7_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_452f7_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_452f7_row0_col23" class="data row0 col23" >1</td>
#       <td id="T_452f7_row0_col24" class="data row0 col24" >1</td>
#       <td id="T_452f7_row0_col25" class="data row0 col25" >0</td>
#     </tr>
#     <tr>
#       <th id="T_452f7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_452f7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_452f7_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_452f7_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_452f7_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_452f7_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_452f7_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_452f7_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_452f7_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_452f7_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_452f7_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_452f7_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_452f7_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_452f7_row1_col12" class="data row1 col12" >0</td>
#       <td i

# %% [markdown]
# ## <a><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:200%;text-align:center;border-radius:5px 5px;padding : 2px">Join the scaled and one-hot encoded columns</p>   </span></font></center>

# %%
train_df_1 = pd.concat([ohe_train, scaled_train], axis =1)
test_df = pd.concat([ohe_test, scaled_test], axis =1)
set_frame_style(train_df_1.head())
# Out:
# <style type="text/css">
# #T_42f32 caption {
#   color: Brown;
#   font-size: 20px;
#   font-weight: bold;
# }
# #T_42f32_row0_col0, #T_42f32_row0_col3, #T_42f32_row0_col6, #T_42f32_row0_col8, #T_42f32_row0_col14, #T_42f32_row0_col20, #T_42f32_row0_col23, #T_42f32_row0_col24, #T_42f32_row0_col31, #T_42f32_row0_col33, #T_42f32_row1_col0, #T_42f32_row1_col2, #T_42f32_row1_col6, #T_42f32_row1_col8, #T_42f32_row1_col13, #T_42f32_row1_col20, #T_42f32_row1_col23, #T_42f32_row1_col25, #T_42f32_row1_col26, #T_42f32_row1_col30, #T_42f32_row1_col35, #T_42f32_row2_col0, #T_42f32_row2_col2, #T_42f32_row2_col7, #T_42f32_row2_col8, #T_42f32_row2_col16, #T_42f32_row2_col21, #T_42f32_row2_col22, #T_42f32_row2_col25, #T_42f32_row2_col32, #T_42f32_row2_col36, #T_42f32_row3_col1, #T_42f32_row3_col3, #T_42f32_row3_col7, #T_42f32_row3_col8, #T_42f32_row3_col14, #T_42f32_row3_col20, #T_42f32_row3_col22, #T_42f32_row3_col24, #T_42f32_row3_col27, #T_42f32_row3_col28, #T_42f32_row3_col29, #T_42f32_row3_col34, #T_42f32_row3_col36, #T_42f32_row4_col0, #T_42f32_row4_col2, #T_42f32_row4_col7, #T_42f32_row4_col9, #T_42f32_row4_col15, #T_42f32_row4_col20, #T_42f32_row4_col23, #T_42f32_row4_col25 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_42f32_row0_col1, #T_42f32_row0_col2, #T_42f32_row0_col4, #T_42f32_row0_col5, #T_42f32_row0_col7, #T_42f32_row0_col9, #T_42f32_row0_col10, #T_42f32_row0_col11, #T_42f32_row0_col12, #T_42f32_row0_col13, #T_42f32_row0_col15, #T_42f32_row0_col16, #T_42f32_row0_col17, #T_42f32_row0_col18, #T_42f32_row0_col19, #T_42f32_row0_col21, #T_42f32_row0_col22, #T_42f32_row0_col25, #T_42f32_row0_col27, #T_42f32_row1_col1, #T_42f32_row1_col3, #T_42f32_row1_col4, #T_42f32_row1_col5, #T_42f32_row1_col7, #T_42f32_row1_col9, #T_42f32_row1_col10, #T_42f32_row1_col11, #T_42f32_row1_col12, #T_42f32_row1_col14, #T_42f32_row1_col15, #T_42f32_row1_col16, #T_42f32_row1_col17, #T_42f32_row1_col18, #T_42f32_row1_col19, #T_42f32_row1_col21, #T_42f32_row1_col22, #T_42f32_row1_col24, #T_42f32_row1_col31, #T_42f32_row1_col32, #T_42f32_row1_col34, #T_42f32_row1_col36, #T_42f32_row2_col1, #T_42f32_row2_col3, #T_42f32_row2_col4, #T_42f32_row2_col5, #T_42f32_row2_col6, #T_42f32_row2_col9, #T_42f32_row2_col10, #T_42f32_row2_col11, #T_42f32_row2_col12, #T_42f32_row2_col13, #T_42f32_row2_col14, #T_42f32_row2_col15, #T_42f32_row2_col17, #T_42f32_row2_col18, #T_42f32_row2_col19, #T_42f32_row2_col20, #T_42f32_row2_col23, #T_42f32_row2_col24, #T_42f32_row2_col26, #T_42f32_row2_col28, #T_42f32_row2_col33, #T_42f32_row3_col0, #T_42f32_row3_col2, #T_42f32_row3_col4, #T_42f32_row3_col5, #T_42f32_row3_col6, #T_42f32_row3_col9, #T_42f32_row3_col10, #T_42f32_row3_col11, #T_42f32_row3_col12, #T_42f32_row3_col13, #T_42f32_row3_col15, #T_42f32_row3_col16, #T_42f32_row3_col17, #T_42f32_row3_col18, #T_42f32_row3_col19, #T_42f32_row3_col21, #T_42f32_row3_col23, #T_42f32_row3_col25, #T_42f32_row3_col30, #T_42f32_row4_col1, #T_42f32_row4_col3, #T_42f32_row4_col4, #T_42f32_row4_col5, #T_42f32_row4_col6, #T_42f32_row4_col8, #T_42f32_row4_col10, #T_42f32_row4_col11, #T_42f32_row4_col12, #T_42f32_row4_col13, #T_42f32_row4_col14, #T_42f32_row4_col16, #T_42f32_row4_col17, #T_42f32_row4_col18, #T_42f32_row4_col19, #T_42f32_row4_col21, #T_42f32_row4_col22, #T_42f32_row4_col24, #T_42f32_row4_col29, #T_42f32_row4_col35 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_42f32_row0_col26 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_42f32_row0_col28 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_42f32_row0_col29 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_42f32_row0_col30, #T_42f32_row3_col26 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_42f32_row0_col32, #T_42f32_row2_col35 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_42f32_row0_col34 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_42f32_row0_col35 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_42f32_row0_col36 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_42f32_row1_col27 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_42f32_row1_col28 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_42f32_row1_col29 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_42f32_row1_col33 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_42f32_row2_col27 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_42f32_row2_col29, #T_42f32_row3_col32 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_42f32_row2_col30 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_42f32_row2_col31 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_42f32_row2_col34 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_42f32_row3_col31, #T_42f32_row4_col31 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_42f32_row3_col33 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_42f32_row3_col35 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_42f32_row4_col26 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_42f32_row4_col27 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_42f32_row4_col28 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_42f32_row4_col30 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_42f32_row4_col32 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_42f32_row4_col33 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_42f32_row4_col34 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_42f32_row4_col36 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42f32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42f32_level0_col0" class="col_heading level0 col0" >Drug_D-penicillamine</th>
#       <th id="T_42f32_level0_col1" class="col_heading level0 col1" >Drug_Placebo</th>
#       <th id="T_42f32_level0_col2" class="col_heading level0 col2" >Sex_F</th>
#       <th id="T_42f32_level0_col3" class="col_heading level0 col3" >Sex_M</th>
#       <th id="T_42f32_level0_col4" class="col_heading level0 col4" >Ascites_N</th>
#       <th id="T_42f32_level0_col5" class="col_heading level0 col5" >Ascites_Y</th>
#       <th id="T_42f32_level0_col6" class="col_heading level0 col6" >Hepatomegaly_N</th>
#       <th id="T_42f32_level0_col7" class="col_heading level0 col7" >Hepatomegaly_Y</th>
#       <th id="T_42f32_level0_col8" class="col_heading level0 col8" >Spiders_N</th>
#       <th id="T_42f32_level0_col9" class="col_heading level0 col9" >Spiders_Y</th>
#       <th id="T_42f32_level0_col10" class="col_heading level0 col10" >Edema_N</th>
#       <th id="T_42f32_level0_col11" class="col_heading level0 col11" >Edema_S</th>
#       <th id="T_42f32_level0_col12" class="col_heading level0 col12" >Edema_Y</th>
#       <th id="T_42f32_level0_col13" class="col_heading level0 col13" >Stage_1.0</th>
#       <th id="T_42f32_level0_col14" class="col_heading level0 col14" >Stage_2.0</th>
#       <th id="T_42f32_level0_col15" class="col_heading level0 col15" >Stage_3.0</th>
#       <th id="T_42f32_level0_col16" class="col_heading level0 col16" >Stage_4.0</th>
#       <th id="T_42f32_level0_col17" class="col_heading level0 col17" >thrombocytopenia_0</th>
#       <th id="T_42f32_level0_col18" class="col_heading level0 col18" >thrombocytopenia_1</th>
#       <th id="T_42f32_level0_col19" class="col_heading level0 col19" >elevated_alk_phos_1</th>
#       <th id="T_42f32_level0_col20" class="col_heading level0 col20" >normal_copper_0</th>
#       <th id="T_42f32_level0_col21" class="col_heading level0 col21" >normal_copper_1</th>
#       <th id="T_42f32_level0_col22" class="col_heading level0 col22" >normal_albumin_0</th>
#       <th id="T_42f32_level0_col23" class="col_heading level0 col23" >normal_albumin_1</th>
#       <th id="T_42f32_level0_col24" class="col_heading level0 col24" >normal_bilirubin_0</th>
#       <th id="T_42f32_level0_col25" class="col_heading level0 col25" >normal_bilirubin_1</th>
#       <th id="T_42f32_level0_col26" class="col_heading level0 col26" >N_Days</th>
#       <th id="T_42f32_level0_col27" class="col_heading level0 col27" >Age</th>
#       <th id="T_42f32_level0_col28" cl

# %%
train_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8181 entries, 0 to 8180
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Drug_D-penicillamine  8181 non-null   int64
#  1   Drug_Placebo          8181 non-null   int64
#  2   Sex_F                 8181 non-null   int64
#  3   Sex_M                 8181 non-null   int64
#  4   Ascites_N             8181 non-null   int64
#  5   Ascites_Y             8181 non-null   int64
#  6   Hepatomegaly_N        8181 non-null   int64
#  7   Hepatomegaly_Y        8181 non-null   int64
#  8   Spiders_N             8181 non-null   int64
#  9   Spiders_Y             8181 non-null   int64
#  10  Edema_N               8181 non-null   int64
#  11  Edema_S               8181 non-null   int64
#  12  Edema_Y               8181 non-null   int64
#  13  Stage_1.0             8181 non-null   int64
#  14  Stage_2.0             8181 non-null   int64
#  15  Stage_3.0             8181 non-null   int64
#  16  Stage_4.0             8181 non-null   int64
#  17  thrombocytopenia_0    8181 non-null   int64
#  18  thrombocytopenia_1    8181 non-null   int64
#  19  elevated_alk_phos_1   8181 non-null   int64
#  20  normal_copper_0       8181 non-null   int64
#  21  normal_copper_1       8181 non-null   int64
#  22  normal_albumin_0      8181 non-null   int64
#  23  normal_albumin_1      8181 non-null   int64
#  24  normal_bilirubin_0    8181 non-null   int64
#  25  normal_bilirubin_1    8181 non-null   int64
#  26  N_Days                8181 non-null   float64
#  27  Age                   8181 non-null   float64
#  28  Bilirubin             8181 non-null   float64
#  29  Cholesterol           8181 non-null   float64
#  30  Albumin               8181 non-null   float64
#  31  Copper                8181 non-null   float64
#  32  Alk_Phos              8181 non-null   float64
#  33  SGOT                  8181 non-null   float64
#  34  Tryglicerides         8181 non-null   float64
#  35  Platelets             8181 non-null   float64
#  36  Prothrombin           8181 non-null   float64
# dtypes: float64(11), int64(26)
# memory usage: 2.3 MB

# %%
train_df_1.shape
# Out:
# (8181, 37)

# %%
from imblearn.under_sampling import TomekLinks
    
def tomek_links (X,y) : 
    '''Tomek Links are pairs of instances, one from the majority class and one from the minority class,
    that are very close to each other in the feature space. They are used in the context of dealing with
    imbalanced datasets to help balance the class distribution. The key idea is to 
    identify and remove those majority class instances that are near the minority class instances'''

    tl = TomekLinks(sampling_strategy='auto')

    X_resampled, y_resampled = tl.fit_resample(X, y)
    
    return X_resampled , y_resampled

# %% [markdown]
# ## <a id="5"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Model Training</p>   </span></font></center>

# %% [markdown]
# # 🤖 Training

# %% [markdown]
# ## <a id="5.1"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">XGBClassifier</p>   </span></font></center>

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import log_loss

X = train_df_1
y = df['Status']

# Label encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X, y_encoded = tomek_links(X, y_encoded)

xgb_params ={'max_depth': 10,
         'min_child_weight': 7,
         'learning_rate': 0.03419253503641095,
         'n_estimators': 472, 
         'subsample': 0.8843005833909504,
         'colsample_bytree': 0.0966352677605082,
         'random_state': 42, 
         'tree_method': 'hist', 
        'eval_metric': 'mlogloss', 
          'device' : 'cuda',
        'verbosity': 2, }

# number of folds
n_splits = 12

#  StratifiedKFold
stratkf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

#  cross-validation results
cv_results = []

# stratified k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(stratkf.split(X, y_encoded)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]


    # XGBoost model
    xgb_model = XGBClassifier(**xgb_params )

    xgb_model.fit(X_train, y_train )

    # predictions on the validation set
    y_val_pred_prob = xgb_model.predict_proba(X_val)

    # Evaluating the model
    logloss = log_loss(y_val, y_val_pred_prob)
    print(f'Fold {fold + 1}, Logarithmic Loss on Validation Set: {logloss}')

    # results
    cv_results.append(logloss)

# average cross-validation result
average_cv_result = sum(cv_results) / n_splits
print(f'\nAverage Logarithmic Loss across {n_splits} folds: {average_cv_result}')
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning:
#
# [10:32:08] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
# Fold 1, Logarithmic Loss on Validation Set: 0.3699113263631317
# Fold 2, Logarithmic Loss on Validation Set: 0.39097842792321036
# Fold 3, Logarithmic Loss on Validation Set: 0.4037723314362947
# Fold 4, Logarithmic Loss on Validation Set: 0.37228489536253917
# Fold 5, Logarithmic Loss on Validation Set: 0.36348031697513006
# Fold 6, Logarithmic Loss on Validation Set: 0.3715753826963224
# Fold 7, Logarithmic Loss on Validation Set: 0.36048785997248095
# Fold 8, Logarithmic Loss on Validation Set: 0.35468701081293713
# Fold 9, Logarithmic Loss on Validation Set: 0.36239563890879967
# Fold 10, Logarithmic Loss on Validation Set: 0.33635757641145525
# Fold 11, Logarithmic Loss on Validation Set: 0.378041145467973
# Fold 12, Logarithmic Loss on Validation Set: 0.40233352681240975
#
# Average Logarithmic Loss across 12 folds: 0.37219211992855694

# %%
import matplotlib.pyplot as plt
feature_importances = xgb_model.feature_importances_
feature_names = train_df_1.columns 
feature_importance_dict = dict(zip(feature_names, feature_importances))
sorted_feature_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)
sorted_feature_names, sorted_importance_scores = zip(*sorted_feature_importance)
plt.figure(figsize=(10, 10))

plt.barh(sorted_feature_names, sorted_importance_scores)
plt.xlabel("Feature Importance")
plt.ylabel("Feature Name")
plt.title("Feature Importance")
plt.show()

# %%
train_df_1.columns
# Out:
# Index(['Drug_D-penicillamine', 'Drug_Placebo', 'Sex_F', 'Sex_M', 'Ascites_N',
#        'Ascites_Y', 'Hepatomegaly_N', 'Hepatomegaly_Y', 'Spiders_N',
#        'Spiders_Y', 'Edema_N', 'Edema_S', 'Edema_Y', 'Stage_1.0', 'Stage_2.0',
#        'Stage_3.0', 'Stage_4.0', 'thrombocytopenia_0', 'thrombocytopenia_1',
#        'elevated_alk_phos_1', 'normal_copper_0', 'normal_copper_1',
#        'normal_albumin_0', 'normal_albumin_1', 'normal_bilirubin_0',
#        'normal_bilirubin_1', 'N_Days', 'Age', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin'],
#       dtype='object')

# %% [markdown]
# ## <a id="5.2"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">LGBM Classifier</p>   </span></font></center>

# %% [markdown]
# # LightGBM

# %%
import lightgbm as lgb
from sklearn.metrics import log_loss
from lightgbm import LGBMClassifier

lgbm_params = {'objective': 'multi_logloss', 
               'max_depth': 9, 'min_child_samples': 14, 
               'learning_rate': 0.034869481921747415, 
               'n_estimators': 274, 'min_child_weight': 9, 
               'subsample': 0.7717873512945741, 
               'colsample_bytree': 0.1702910221565107, 
               'reg_alpha': 0.10626128775335533, 
               'reg_lambda': 0.624196407787772, 
               'random_state': 42}

# folds
n_splits = 12

# StratifiedKFold
stratkf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

cv_results = []

for fold, (train_idx, val_idx) in enumerate(stratkf.split(X, y_encoded)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]

    lgbm_model = LGBMClassifier(**lgbm_params)
    lgbm_model.fit(X_train,y_train)

    y_val_pred_prob = lgbm_model.predict_proba(X_val)

    logloss = log_loss(y_val, y_val_pred_prob)
    print(f'Fold {fold + 1}, Logarithmic Loss on Validation Set: {logloss}')

    cv_results.append(logloss)
average_cv_result = sum(cv_results) / n_splits
print(f'\nAverage Logarithmic Loss across {n_splits} folds: {average_cv_result}')
# Out:
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning:
#
# You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
# Fold 1, Logarithmic Loss on Validation Set: 0.3639589514936783
# Fold 2, Logarithmic Loss on Validation Set: 0.3897759380919587
# Fold 3, Logarithmic Loss on Validation Set: 0.41204252504221334
# Fold 4, Logarithmic Loss on Validation Set: 0.36734639085920057
# Fold 5, Logarithmic Loss on Validation Set: 0.3592964918299174
# Fold 6, Logarithmic Loss on Validation Set: 0.3737273030749677
# Fold 7, Logarithmic Loss on Validation Set: 0.36616341559644233
# Fold 8, Logarithmic Loss on Validation Set: 0.36231358830386573
# Fold 9, Logarithmic Loss on Validation Set: 0.3628521603221743
# Fold 10, Logarithmic Loss on Validation Set: 0.33897037152073867
# Fold 11, Logarithmic Loss on Validation Set: 0.3886954974490185
# Fold 12, Logarithmic Loss on Validation Set: 0.40462281004687084
#
# Average Logarithmic Loss across 12 folds: 0.3741471203025873

# %% [markdown]
# ## <a id="5.3"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Catboost Classifier</p>   </span></font></center>

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostClassifier
catboost_params = {'iterations': 469,
                   'depth': 20, 
                   'min_data_in_leaf': 11,
                   'learning_rate': 0.13812945166006543, 
                   'grow_policy': 'Lossguide',
                   'bootstrap_type' : 'Bernoulli'}

n_splits = 12

stratkf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)


cv_results = []


for fold, (train_idx, val_idx) in enumerate(stratkf.split(X, y_encoded)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]

    cat_model = CatBoostClassifier(**catboost_params, 
                            random_state=42, verbose =0
                           )
    cat_model.fit(X_train,y_train)

 
    y_val_pred_prob = cat_model.predict_proba(X_val)

    logloss = log_loss(y_val, y_val_pred_prob)
    print(f'Fold {fold + 1}, Logarithmic Loss on Validation Set: {logloss}')

 
    cv_results.append(logloss)

average_cv_result = sum(cv_results) / n_splits
print(f'\nAverage Logarithmic Loss across {n_splits} folds: {average_cv_result}')
# Out:
# Fold 1, Logarithmic Loss on Validation Set: 0.3781974232591213
# Fold 2, Logarithmic Loss on Validation Set: 0.41963981802659883
# Fold 3, Logarithmic Loss on Validation Set: 0.4447141559689915
# Fold 4, Logarithmic Loss on Validation Set: 0.3713121151267267
# Fold 5, Logarithmic Loss on Validation Set: 0.3653864126965935
# Fold 6, Logarithmic Loss on Validation Set: 0.38082403477115234
# Fold 7, Logarithmic Loss on Validation Set: 0.37212779471467333
# Fold 8, Logarithmic Loss on Validation Set: 0.3783035956224813
# Fold 9, Logarithmic Loss on Validation Set: 0.37802678307863297
# Fold 10, Logarithmic Loss on Validation Set: 0.3403982953241245
# Fold 11, Logarithmic Loss on Validation Set: 0.4123558240505187
# Fold 12, Logarithmic Loss on Validation Set: 0.42392298858959254
#
# Average Logarithmic Loss across 12 folds: 0.3887674367691007

# %% [markdown]
# ## <a id="5.5"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Ensemble of XGB, CATBOOST and LGBM</p>   </span></font></center>

# %% [markdown]
# # Ensemble

# %%
from sklearn.ensemble import VotingClassifier

Ensemble = VotingClassifier(estimators = [('lgb', lgbm_model), ('xgb', xgb_model), ('CB', cat_model)], 
                            voting='soft',
                            weights = [0.45,0.5,0.05]   #Adjust weighting since XGB performs better in local environment
                            )
Ensemble.fit(X, y_encoded)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(colsample_bytree=0.1702910221565107,
#                                              learning_rate=0.034869481921747415,
#                                              max_depth=9, min_child_samples=14,
#                                              min_child_weight=9,
#                                              n_estimators=274,
#                                              objective='multi_logloss',
#                                              random_state=42,
#                                              reg_alpha=0.10626128775335533,
#                                              reg_lambda=0.624196407787772,
#                                              subsample=0.7717873512945741)),
#                              ('xgb',
#                               XGBClassifier(base_s...
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=10,
#                                             max_leaves=None, min_child_weight=7,
#                                             missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=472, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('CB',
#                               <catboost.core.CatBoostClassifier object at 0x79e91fc45780>)],
#                  voting='soft', weights=[0.45, 0.5, 0.05])

# %% [markdown]
# ## <a id="6.1"><center><font size = 4><span style="color:#F5F5E6"> <p style="background-color:#003B39;font-family:courier;color:#FFFFFF;font-size:250%;text-align:center;border-radius:5px 5px;padding : 2px">Feature Importance</p>   </span></font></center>

# %% [markdown]
# # Feature Importance

# %%
import matplotlib.pyplot as plt
feature_importances = xgb_model.feature_importances_
feature_names = train_df_1.columns 
feature_importance_dict = dict(zip(feature_names, feature_importances))
sorted_feature_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)
sorted_feature_names, sorted_importance_scores = zip(*sorted_feature_importance)
plt.figure(figsize=(10, 10))

plt.barh(sorted_feature_names, sorted_importance_scores)
plt.xlabel("Feature Importance")
plt.ylabel("Feature Name")
plt.title("Feature Importance")
plt.show()

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5271 entries, 0 to 5270
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Drug_D-penicillamine  5271 non-null   int64
#  1   Drug_Placebo          5271 non-null   int64
#  2   Sex_F                 5271 non-null   int64
#  3   Sex_M                 5271 non-null   int64
#  4   Ascites_N             5271 non-null   int64
#  5   Ascites_Y             5271 non-null   int64
#  6   Hepatomegaly_N        5271 non-null   int64
#  7   Hepatomegaly_Y        5271 non-null   int64
#  8   Spiders_N             5271 non-null   int64
#  9   Spiders_Y             5271 non-null   int64
#  10  Edema_N               5271 non-null   int64
#  11  Edema_S               5271 non-null   int64
#  12  Edema_Y               5271 non-null   int64
#  13  Stage_1.0             5271 non-null   int64
#  14  Stage_2.0             5271 non-null   int64
#  15  Stage_3.0             5271 non-null   int64
#  16  Stage_4.0             5271 non-null   int64
#  17  thrombocytopenia_0    5271 non-null   int64
#  18  thrombocytopenia_1    5271 non-null   int64
#  19  elevated_alk_phos_1   5271 non-null   int64
#  20  normal_copper_0       5271 non-null   int64
#  21  normal_copper_1       5271 non-null   int64
#  22  normal_albumin_0      5271 non-null   int64
#  23  normal_albumin_1      5271 non-null   int64
#  24  normal_bilirubin_0    5271 non-null   int64
#  25  normal_bilirubin_1    5271 non-null   int64
#  26  N_Days                5271 non-null   float64
#  27  Age                   5271 non-null   float64
#  28  Bilirubin             5271 non-null   float64
#  29  Cholesterol           5271 non-null   float64
#  30  Albumin               5271 non-null   float64
#  31  Copper                5271 non-null   float64
#  32  Alk_Phos              5271 non-null   float64
#  33  SGOT                  5271 non-null   float64
#  34  Tryglicerides         5271 non-null   float64
#  35  Platelets             5271 non-null   float64
#  36  Prothrombin           5271 non-null   float64
# dtypes: float64(11), int64(26)
# memory usage: 1.5 MB

# %%
train_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8181 entries, 0 to 8180
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Drug_D-penicillamine  8181 non-null   int64
#  1   Drug_Placebo          8181 non-null   int64
#  2   Sex_F                 8181 non-null   int64
#  3   Sex_M                 8181 non-null   int64
#  4   Ascites_N             8181 non-null   int64
#  5   Ascites_Y             8181 non-null   int64
#  6   Hepatomegaly_N        8181 non-null   int64
#  7   Hepatomegaly_Y        8181 non-null   int64
#  8   Spiders_N             8181 non-null   int64
#  9   Spiders_Y             8181 non-null   int64
#  10  Edema_N               8181 non-null   int64
#  11  Edema_S               8181 non-null   int64
#  12  Edema_Y               8181 non-null   int64
#  13  Stage_1.0             8181 non-null   int64
#  14  Stage_2.0             8181 non-null   int64
#  15  Stage_3.0             8181 non-null   int64
#  16  Stage_4.0             8181 non-null   int64
#  17  thrombocytopenia_0    8181 non-null   int64
#  18  thrombocytopenia_1    8181 non-null   int64
#  19  elevated_alk_phos_1   8181 non-null   int64
#  20  normal_copper_0       8181 non-null   int64
#  21  normal_copper_1       8181 non-null   int64
#  22  normal_albumin_0      8181 non-null   int64
#  23  normal_albumin_1      8181 non-null   int64
#  24  normal_bilirubin_0    8181 non-null   int64
#  25  normal_bilirubin_1    8181 non-null   int64
#  26  N_Days                8181 non-null   float64
#  27  Age                   8181 non-null   float64
#  28  Bilirubin             8181 non-null   float64
#  29  Cholesterol           8181 non-null   float64
#  30  Albumin               8181 non-null   float64
#  31  Copper                8181 non-null   float64
#  32  Alk_Phos              8181 non-null   float64
#  33  SGOT                  8181 non-null   float64
#  34  Tryglicerides         8181 non-null   float64
#  35  Platelets             8181 non-null   float64
#  36  Prothrombin           8181 non-null   float64
# dtypes: float64(11), int64(26)
# memory usage: 2.3 MB

# %% [markdown]
# # Final Submission

# %%
y_pred = xgb_model.predict_proba(test_df)
y_pred = pd.DataFrame(y_pred)
y_pred.columns = ['Status_C', 'Status_CL','Status_D']
y_pred.head()
# Out:
#    Status_C  Status_CL  Status_D
# 0  0.574535   0.027518  0.397947
# 1  0.517870   0.189733  0.292397
# 2  0.042635   0.021604  0.935762
# 3  0.985205   0.003986  0.010808
# 4  0.837527   0.079274  0.083199

# %%
submission_df = pd.DataFrame()
submission_df = y_pred
submission_df['id'] = ids
submission_df.head()
# Out:
#    Status_C  Status_CL  Status_D    id
# 0  0.574535   0.027518  0.397947  7905
# 1  0.517870   0.189733  0.292397  7906
# 2  0.042635   0.021604  0.935762  7907
# 3  0.985205   0.003986  0.010808  7908
# 4  0.837527   0.079274  0.083199  7909

# %%
submission_df.to_csv('submission.csv', index= False)
